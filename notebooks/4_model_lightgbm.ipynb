# %% [markdown]
# # LightGBM Model Development
#
# LightGBM is a gradient boosting framework that uses tree-based learning algorithms. It is designed to be distributed and efficient with the following advantages:
#
# -   Faster training speed and higher efficiency.
# -   Lower memory usage.
# -   Better accuracy.
# -   Support of parallel, distributed, and GPU learning.
# -   Capable of handling large-scale data.
#
# In this notebook, we will:
#
# 1.  **Load the Datasets**: Load the processed training, validation, and test datasets.
# 2.  **Hyperparameter Tuning & Model Training**: Use Optuna to find the best hyperparameters for a LightGBM model, and then train the model.

# %% [markdown]
# ### 1. Load the Datasets

# %%
import pandas as pd
from pathlib import Path

# Directory where the processed data is stored
data_path = Path("../processed_data")

# Load the training and validation datasets
X_train, X_val, y_train, y_val = (
    pd.read_csv(data_path / "X_train.csv"),
    pd.read_csv(data_path / "X_val.csv"),
    pd.read_csv(data_path / "y_train.csv"),
    pd.read_csv(data_path / "y_val.csv")
)

# Combine train and validation sets for robust K-Fold tuning
features = pd.concat([X_train, X_val], ignore_index=True)
targets = pd.concat([y_train, y_val], ignore_index=True)

# Display the shapes of the datasets
print(f"Features shape: {features.shape}")
print(f"Targets shape: {targets.shape}")
# Out:
# Features shape: (2000, 157)
# Targets shape: (2000, 10)

# %% [markdown]
# ### 2. Hyperparameter Tuning & Model Training
#
# **K-Fold Cross-Validation**: It is a technique used to evaluate the performance and generalization ability of a model. The training data is divided into 'K' subsets or folds. The model is trained 'K' times, each time using a different fold as the validation set and the remaining folds as the training set. The results are then averaged across all folds to provide a more robust estimate of the model's performance, reducing the risk of overfitting to a specific training or validation set.
#
# **Optuna**: It is an open-source hyperparameter optimization framework that automates the process of finding the best set of hyperparameters for a machine learning model. It uses sophisticated algorithms to efficiently search the hyperparameter space, balancing exploration of new parameter combinations with exploitation of promising ones. Optuna helps to maximize the performance of the model by identifying the optimal hyperparameter settings.
#
# **Mean Absolute Percentage Error (MAPE)**: It is a metric used to measure the accuracy of a forecasting method. It calculates the average absolute percentage difference between the predicted and actual values. MAPE is scale-independent and easy to interpret, making it a popular choice for evaluating the performance of regression models, especially when the target variable is positive. A lower MAPE indicates higher accuracy of the model.

# %%
import optuna
import warnings
import numpy as np
import lightgbm as lgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_percentage_error

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")

# Define the objective function for Optuna
def objective(trial: optuna.Trial, X: pd.DataFrame, y: pd.Series):
    """
    Objective function for Optuna to minimize.
    This function trains a LightGBM model with a set of hyperparameters
    suggested by Optuna and returns the cross-validated MAPE.

    Parameters:
      trial (optuna.Trial): An Optuna trial object that suggests hyperparameters.
      X (pd.DataFrame): Feature matrix for training.
      y (pd.Series): Target variable for training.

    Returns:
      float: The mean absolute percentage error (MAPE) of the model on the validation set during cross-validation.
    """
    # Define the hyperparameter search space for LightGBM
    param = {
        'objective': 'regression_l1',                                         # Specify the objective function as L1 regression (Mean Absolute Error)
        'metric': 'mape',                                                     # Use Mean Absolute Percentage Error as the evaluation metric
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),         # Number of boosting rounds (trees) - suggested by Optuna
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),      # Step size shrinkage to prevent overfitting - suggested by Optuna
        'num_leaves': trial.suggest_int('num_leaves', 20, 300),               # Number of leaves in one tree - suggested by Optuna
        'max_depth': trial.suggest_int('max_depth', 3, 12),                   # Limit the depth of tree to prevent overfitting - suggested by Optuna
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),  # Minimum number of data needed in a leaf - suggested by Optuna
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),               # Fraction of training data to be used for each boosting round - suggested by Optuna
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0), # Fraction of features to be used for each tree - suggested by Optuna
        'random_state': 42,                                                   # Random seed for reproducibility
        'n_jobs': -1,                                                         # Use all available cores for training
        'verbose':-1                                                          # Suppress verbose output from LightGBM
    }

    # --- Perform K-Fold cross-validation ---
    # This splits the data into K folds, trains the model on K-1 folds, and validates it on the remaining fold, repeating this process K times.
    # The mean absolute percentage error (MAPE) is calculated for each fold, and the average MAPE across all folds is returned as the objective value.
    # This helps in assessing the model's performance more robustly by reducing variance.
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    mape_scores = []
    for train_index, val_index in kf.split(X):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        model = lgb.LGBMRegressor(**param)
        model.fit(X_train, y_train, eval_set=[(X_val, y_val)], callbacks=[lgb.early_stopping(10, verbose=False)])
        preds = model.predict(X_val)
        mape_scores.append(mean_absolute_percentage_error(y_val, preds))

    return np.mean(mape_scores)

# %%
import joblib

# Define the directory for saving models and Optuna studies
model_dir = Path("../models/lightgbm")
model_dir.mkdir(parents=True, exist_ok=True)

optuna_dir = Path("../optuna_db")
optuna_dir.mkdir(parents=True, exist_ok=True)
storage_name = f"sqlite:///{optuna_dir}/lightgbm_studies.db"

# Dictionary to store the best models
best_models = {}

# Iterate over each target property to tune and train a model
for target in targets.columns:
    print(f"\n--- TUNING AND TRAINING FOR {target} ---\n")
    y = targets[target]


    # Create an Optuna study to find the best hyperparameters
    study = optuna.create_study(direction='minimize',
                                study_name='lightgbm-tuning-' + target,
                                storage=storage_name)
    study.optimize(lambda trial: objective(trial, features, y), n_trials=100)

    # Get the best hyperparameters
    best_params = study.best_params
    print(f"\nBEST MAPE FOR {target}: {study.best_value}")
    print(f"BEST HYPERPARAMETERS FOR {target}: {best_params}")

    # Train the final model with the best hyperparameters on the entire training set
    final_model = lgb.LGBMRegressor(**best_params, random_state=42, n_jobs=-1)
    final_model.fit(features, y)

    # Save the trained model to a file
    joblib.dump(final_model, f'{model_dir}/{target}_model.joblib')
    print(f"Saved best model for {target}")

    # Store the best model with its MAPE score in the dictionary
    best_models[target] = (final_model, study.best_value)
# Out:
# --- TUNING AND TRAINING FOR BlendProperty1 ---
# [I 2025-07-18 08:03:20,913] A new study created in RDB with name: lightgbm-tuning-BlendProperty1
# [I 2025-07-18 08:03:32,910] Trial 0 finished with value: 0.6775153832726067 and parameters: {'n_estimators': 623, 'learning_rate': 0.02550234740429879, 'num_leaves': 153, 'max_depth': 8, 'min_child_samples': 62, 'subsample': 0.987840076924557, 'colsample_bytree': 0.9037467807059227}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:03:40,202] Trial 1 finished with value: 3.081374529376782 and parameters: {'n_estimators': 453, 'learning_rate': 0.10631937672293254, 'num_leaves': 62, 'max_depth': 11, 'min_child_samples': 38, 'subsample': 0.97000069837888, 'colsample_bytree': 0.7394274698874774}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:03:47,033] Trial 2 finished with value: 0.6824005309100417 and parameters: {'n_estimators': 698, 'learning_rate': 0.024529746336448423, 'num_leaves': 110, 'max_depth': 6, 'min_child_samples': 94, 'subsample': 0.6191329235492551, 'colsample_bytree': 0.730675986701881}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:03:50,207] Trial 3 finished with value: 2.515613090629965 and parameters: {'n_estimators': 169, 'learning_rate': 0.016299384593183183, 'num_leaves': 104, 'max_depth': 6, 'min_child_samples': 47, 'subsample': 0.7612318696989653, 'colsample_bytree': 0.7303562458111118}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:03:57,334] Trial 4 finished with value: 1.7633780236635779 and parameters: {'n_estimators': 248, 'learning_rate': 0.11098368331506514, 'num_leaves': 295, 'max_depth': 8, 'min_child_samples': 14, 'subsample': 0.6337521711573204, 'colsample_bytree': 0.7134233877301066}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:03:59,740] Trial 5 finished with value: 1.602598262630308 and parameters: {'n_estimators': 198, 'learning_rate': 0.16740887844167598, 'num_leaves': 104, 'max_depth': 9, 'min_child_samples': 59, 'subsample': 0.737464140328437, 'colsample_bytree': 0.6406761412330478}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:04:02,432] Trial 6 finished with value: 1.357475307860335 and parameters: {'n_estimators': 343, 'learning_rate': 0.2204536463860664, 'num_leaves': 21, 'max_depth': 12, 'min_child_samples': 69, 'subsample': 0.8599905959885417, 'colsample_bytree': 0.605204996318496}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:04:04,287] Trial 7 finished with value: 5.134438436217501 and parameters: {'n_estimators': 514, 'learning_rate': 0.2784490703431354, 'num_leaves': 110, 'max_depth': 9, 'min_child_samples': 70, 'subsample': 0.8049359561039222, 'colsample_bytree': 0.8549059067135161}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:04:05,813] Trial 8 finished with value: 0.969628951278545 and parameters: {'n_estimators': 402, 'learning_rate': 0.19700311694284148, 'num_leaves': 93, 'max_depth': 5, 'min_child_samples': 88, 'subsample': 0.7867970171282881, 'colsample_bytree': 0.6956561315336715}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:04:12,459] Trial 9 finished with value: 3.799754483106798 and parameters: {'n_estimators': 161, 'learning_rate': 0.1657721372746576, 'num_leaves': 179, 'max_depth': 12, 'min_child_samples': 21, 'subsample': 0.6108271076594347, 'colsample_bytree': 0.8450901002879437}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:04:16,362] Trial 10 finished with value: 1.034955616573467 and parameters: {'n_estimators': 957, 'learning_rate': 0.07729693851384514, 'num_leaves': 200, 'max_depth': 3, 'min_child_samples': 37, 'subsample': 0.9727949987637667, 'colsample_bytree': 0.9896692627484175}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:04:24,718] Trial 11 finished with value: 1.1867340265558914 and parameters: {'n_estimators': 750, 'learning_rate': 0.010841334876796754, 'num_leaves': 219, 'max_depth': 6, 'min_child_samples': 83, 'subsample': 0.9064936950528419, 'colsample_bytree': 0.942659393609128}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:04:28,531] Trial 12 finished with value: 1.1349713538333321 and parameters: {'n_estimators': 700, 'learning_rate': 0.060276721908129625, 'num_leaves': 150, 'max_depth': 4, 'min_child_samples': 96, 'subsample': 0.6815541572133019, 'colsample_bytree': 0.8943789307089659}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:04:37,156] Trial 13 finished with value: 1.0688581563418063 and parameters: {'n_estimators': 691, 'learning_rate': 0.06067174063891889, 'num_leaves': 149, 'max_depth': 7, 'min_child_samples': 77, 'subsample': 0.8887786802857655, 'colsample_bytree': 0.7920182107948729}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:04:43,105] Trial 14 finished with value: 1.5083250965340078 and parameters: {'n_estimators': 860, 'learning_rate': 0.03868513254970428, 'num_leaves': 248, 'max_depth': 10, 'min_child_samples': 98, 'subsample': 0.6976836895400816, 'colsample_bytree': 0.7969811492188139}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:04:46,641] Trial 15 finished with value: 1.2222056518586293 and parameters: {'n_estimators': 595, 'learning_rate': 0.11309709520142053, 'num_leaves': 140, 'max_depth': 7, 'min_child_samples': 59, 'subsample': 0.8354644868871557, 'colsample_bytree': 0.9140532441722847}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:05:01,786] Trial 16 finished with value: 1.113594005363659 and parameters: {'n_estimators': 597, 'learning_rate': 0.08939667443362392, 'num_leaves': 64, 'max_depth': 8, 'min_child_samples': 5, 'subsample': 0.9284522317303558, 'colsample_bytree': 0.8415437172027866}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:05:06,285] Trial 17 finished with value: 1.8472423182743842 and parameters: {'n_estimators': 791, 'learning_rate': 0.1320935732955615, 'num_leaves': 183, 'max_depth': 6, 'min_child_samples': 49, 'subsample': 0.6685772330255166, 'colsample_bytree': 0.9931211983585544}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:05:10,913] Trial 18 finished with value: 2.361331293216619 and parameters: {'n_estimators': 993, 'learning_rate': 0.040649589742735755, 'num_leaves': 238, 'max_depth': 4, 'min_child_samples': 71, 'subsample': 0.9932593372546457, 'colsample_bytree': 0.7643862377246781}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:05:17,440] Trial 19 finished with value: 1.8742262772258176 and parameters: {'n_estimators': 879, 'learning_rate': 0.03703800420722886, 'num_leaves': 130, 'max_depth': 9, 'min_child_samples': 89, 'subsample': 0.7313369326710175, 'colsample_bytree': 0.6654341977007141}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:05:18,839] Trial 20 finished with value: 3.290507290046295 and parameters: {'n_estimators': 626, 'learning_rate': 0.2851693965121219, 'num_leaves': 75, 'max_depth': 5, 'min_child_samples': 34, 'subsample': 0.9424504882035217, 'colsample_bytree': 0.8799491304577414}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:05:22,435] Trial 21 finished with value: 4.757440422106722 and parameters: {'n_estimators': 421, 'learning_rate': 0.2040476476935562, 'num_leaves': 33, 'max_depth': 5, 'min_child_samples': 88, 'subsample': 0.7851717628010733, 'colsample_bytree': 0.6893586038821706}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:05:24,242] Trial 22 finished with value: 2.990505962866487 and parameters: {'n_estimators': 338, 'learning_rate': 0.20688152434120693, 'num_leaves': 85, 'max_depth': 5, 'min_child_samples': 99, 'subsample': 0.8349457835394578, 'colsample_bytree': 0.7605029860750057}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:05:26,334] Trial 23 finished with value: 1.552888770900834 and parameters: {'n_estimators': 494, 'learning_rate': 0.2520000165214385, 'num_leaves': 113, 'max_depth': 7, 'min_child_samples': 80, 'subsample': 0.6401667745952156, 'colsample_bytree': 0.6926086506075336}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:05:27,906] Trial 24 finished with value: 4.2154378413966125 and parameters: {'n_estimators': 394, 'learning_rate': 0.18769246337933948, 'num_leaves': 170, 'max_depth': 3, 'min_child_samples': 62, 'subsample': 0.8715025234392083, 'colsample_bytree': 0.6367437792586182}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:05:31,926] Trial 25 finished with value: 3.168055632180658 and parameters: {'n_estimators': 664, 'learning_rate': 0.24168259558917005, 'num_leaves': 53, 'max_depth': 6, 'min_child_samples': 91, 'subsample': 0.7157139082267012, 'colsample_bytree': 0.8208750164313072}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:05:33,936] Trial 26 finished with value: 2.4120693674641815 and parameters: {'n_estimators': 533, 'learning_rate': 0.13720774582417805, 'num_leaves': 128, 'max_depth': 4, 'min_child_samples': 79, 'subsample': 0.7838104150830674, 'colsample_bytree': 0.7717437837266707}. Best is trial 0 with value: 0.6775153832726067.
# [I 2025-07-18 08:05:36,791] Trial 27 finished with value: 0.664480119895121 and parameters: {'n_estimators': 777, 'learning_rate': 0.1476886594008643, 'num_leaves': 92, 'max_depth': 8, 'min_child_samples': 88, 'subsample': 0.8156123302508664, 'colsample_bytree': 0.9540732789631515}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:05:42,663] Trial 28 finished with value: 1.5386072158361865 and parameters: {'n_estimators': 803, 'learning_rate': 0.06995522969906406, 'num_leaves': 43, 'max_depth': 8, 'min_child_samples': 74, 'subsample': 0.6007186444959726, 'colsample_bytree': 0.9554173217897625}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:05:46,683] Trial 29 finished with value: 3.0787865579734572 and parameters: {'n_estimators': 743, 'learning_rate': 0.09729127100997684, 'num_leaves': 123, 'max_depth': 10, 'min_child_samples': 64, 'subsample': 0.9423023424438148, 'colsample_bytree': 0.9377060378598691}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:06:02,298] Trial 30 finished with value: 0.8082246207308785 and parameters: {'n_estimators': 878, 'learning_rate': 0.025733964856462423, 'num_leaves': 78, 'max_depth': 10, 'min_child_samples': 52, 'subsample': 0.8239522000882185, 'colsample_bytree': 0.9709633376864495}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:06:20,360] Trial 31 finished with value: 2.416851364172006 and parameters: {'n_estimators': 905, 'learning_rate': 0.03192313219115001, 'num_leaves': 71, 'max_depth': 10, 'min_child_samples': 43, 'subsample': 0.8224665868085697, 'colsample_bytree': 0.9737536554040191}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:06:36,679] Trial 32 finished with value: 1.2747402934099625 and parameters: {'n_estimators': 808, 'learning_rate': 0.023825941118049258, 'num_leaves': 87, 'max_depth': 11, 'min_child_samples': 54, 'subsample': 0.7523158768114198, 'colsample_bytree': 0.9102426769585261}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:06:50,136] Trial 33 finished with value: 1.226474609081078 and parameters: {'n_estimators': 922, 'learning_rate': 0.053844549855278756, 'num_leaves': 100, 'max_depth': 8, 'min_child_samples': 29, 'subsample': 0.858958116067529, 'colsample_bytree': 0.9679582895256801}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:07:03,223] Trial 34 finished with value: 1.2254975709433273 and parameters: {'n_estimators': 744, 'learning_rate': 0.01031377159446869, 'num_leaves': 161, 'max_depth': 9, 'min_child_samples': 54, 'subsample': 0.9132618858008129, 'colsample_bytree': 0.9263683992873489}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:07:11,360] Trial 35 finished with value: 0.8681594428149217 and parameters: {'n_estimators': 839, 'learning_rate': 0.08347481811218299, 'num_leaves': 298, 'max_depth': 11, 'min_child_samples': 45, 'subsample': 0.7706135178365869, 'colsample_bytree': 0.8694115627025114}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:07:15,622] Trial 36 finished with value: 2.762582546646873 and parameters: {'n_estimators': 650, 'learning_rate': 0.12181404019629885, 'num_leaves': 53, 'max_depth': 7, 'min_child_samples': 93, 'subsample': 0.6532015712890381, 'colsample_bytree': 0.7257176112748909}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:07:21,741] Trial 37 finished with value: 1.2015641920022666 and parameters: {'n_estimators': 579, 'learning_rate': 0.049743720336556836, 'num_leaves': 113, 'max_depth': 9, 'min_child_samples': 83, 'subsample': 0.809615784676866, 'colsample_bytree': 0.893483095534473}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:07:23,733] Trial 38 finished with value: 2.5613254944760233 and parameters: {'n_estimators': 105, 'learning_rate': 0.14657283032219706, 'num_leaves': 79, 'max_depth': 11, 'min_child_samples': 65, 'subsample': 0.8537340795918218, 'colsample_bytree': 0.959483687474268}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:07:27,396] Trial 39 finished with value: 4.385409075737446 and parameters: {'n_estimators': 747, 'learning_rate': 0.16846443872055372, 'num_leaves': 99, 'max_depth': 8, 'min_child_samples': 57, 'subsample': 0.997857854061207, 'colsample_bytree': 0.8227775594929849}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:07:44,702] Trial 40 finished with value: 2.7628268452339775 and parameters: {'n_estimators': 710, 'learning_rate': 0.02377008149221288, 'num_leaves': 197, 'max_depth': 10, 'min_child_samples': 41, 'subsample': 0.7367296757564864, 'colsample_bytree': 0.7399231111139222}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:07:55,389] Trial 41 finished with value: 1.196678528305103 and parameters: {'n_estimators': 836, 'learning_rate': 0.0844999773196416, 'num_leaves': 250, 'max_depth': 11, 'min_child_samples': 45, 'subsample': 0.7680092209199263, 'colsample_bytree': 0.8653785309877954}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:08:02,618] Trial 42 finished with value: 2.6437783692735413 and parameters: {'n_estimators': 949, 'learning_rate': 0.10035495811676137, 'num_leaves': 288, 'max_depth': 12, 'min_child_samples': 51, 'subsample': 0.710472733050915, 'colsample_bytree': 0.9298098192779104}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:08:14,847] Trial 43 finished with value: 0.9277310319415994 and parameters: {'n_estimators': 838, 'learning_rate': 0.07454685743553002, 'num_leaves': 278, 'max_depth': 12, 'min_child_samples': 29, 'subsample': 0.8852592339143377, 'colsample_bytree': 0.8754353841202597}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:08:33,974] Trial 44 finished with value: 1.822611387567462 and parameters: {'n_estimators': 782, 'learning_rate': 0.020782250615688568, 'num_leaves': 138, 'max_depth': 10, 'min_child_samples': 47, 'subsample': 0.6215857699162318, 'colsample_bytree': 0.9046231679321299}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:08:45,120] Trial 45 finished with value: 1.2306717022436358 and parameters: {'n_estimators': 889, 'learning_rate': 0.0648499359628471, 'num_leaves': 20, 'max_depth': 11, 'min_child_samples': 38, 'subsample': 0.9670294344300632, 'colsample_bytree': 0.9824692275299888}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:08:49,856] Trial 46 finished with value: 1.1227530838061461 and parameters: {'n_estimators': 690, 'learning_rate': 0.04723180540042566, 'num_leaves': 158, 'max_depth': 6, 'min_child_samples': 84, 'subsample': 0.7635235274803094, 'colsample_bytree': 0.9500991756317501}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:08:54,803] Trial 47 finished with value: 3.060926991041706 and parameters: {'n_estimators': 632, 'learning_rate': 0.11404703431492486, 'num_leaves': 214, 'max_depth': 9, 'min_child_samples': 69, 'subsample': 0.8066366709405443, 'colsample_bytree': 0.9954692468056535}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:09:27,320] Trial 48 finished with value: 2.585066244085085 and parameters: {'n_estimators': 998, 'learning_rate': 0.02970000045372543, 'num_leaves': 116, 'max_depth': 9, 'min_child_samples': 16, 'subsample': 0.6671165802599403, 'colsample_bytree': 0.9233902201589967}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:09:35,963] Trial 49 finished with value: 1.0831264942766432 and parameters: {'n_estimators': 846, 'learning_rate': 0.053156622117541935, 'num_leaves': 95, 'max_depth': 8, 'min_child_samples': 95, 'subsample': 0.8423607649058472, 'colsample_bytree': 0.8439835340846653}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:09:51,704] Trial 50 finished with value: 1.3064078721788284 and parameters: {'n_estimators': 768, 'learning_rate': 0.013001084571948845, 'num_leaves': 63, 'max_depth': 7, 'min_child_samples': 33, 'subsample': 0.6877471489774756, 'colsample_bytree': 0.8943039334501982}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:10:07,895] Trial 51 finished with value: 1.959353313112126 and parameters: {'n_estimators': 822, 'learning_rate': 0.07833943979504321, 'num_leaves': 285, 'max_depth': 12, 'min_child_samples': 17, 'subsample': 0.8772266741991636, 'colsample_bytree': 0.8729548454558032}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:10:22,599] Trial 52 finished with value: 1.2820579229737556 and parameters: {'n_estimators': 940, 'learning_rate': 0.07619256385965201, 'num_leaves': 278, 'max_depth': 12, 'min_child_samples': 23, 'subsample': 0.8936884134681614, 'colsample_bytree': 0.8196115462750069}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:10:35,058] Trial 53 finished with value: 1.561544853995542 and parameters: {'n_estimators': 870, 'learning_rate': 0.09238062613036019, 'num_leaves': 259, 'max_depth': 11, 'min_child_samples': 27, 'subsample': 0.8230529624768287, 'colsample_bytree': 0.8597381575748999}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:11:16,113] Trial 54 finished with value: 2.367330564852664 and parameters: {'n_estimators': 718, 'learning_rate': 0.04144378259937741, 'num_leaves': 298, 'max_depth': 12, 'min_child_samples': 11, 'subsample': 0.9584711762983844, 'colsample_bytree': 0.884671957994786}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:11:21,767] Trial 55 finished with value: 2.7517499863895716 and parameters: {'n_estimators': 836, 'learning_rate': 0.16156653586229058, 'num_leaves': 272, 'max_depth': 11, 'min_child_samples': 40, 'subsample': 0.9113824853797019, 'colsample_bytree': 0.9131096325709525}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:11:24,882] Trial 56 finished with value: 1.8477178313928662 and parameters: {'n_estimators': 666, 'learning_rate': 0.17971204898011603, 'num_leaves': 265, 'max_depth': 6, 'min_child_samples': 34, 'subsample': 0.7906865690921541, 'colsample_bytree': 0.9413090614889572}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:11:31,973] Trial 57 finished with value: 1.208873429220196 and parameters: {'n_estimators': 585, 'learning_rate': 0.12683340940959628, 'num_leaves': 230, 'max_depth': 10, 'min_child_samples': 50, 'subsample': 0.876854300161876, 'colsample_bytree': 0.7819585523155288}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:11:36,166] Trial 58 finished with value: 1.2793792507527315 and parameters: {'n_estimators': 870, 'learning_rate': 0.107789033002816, 'num_leaves': 186, 'max_depth': 12, 'min_child_samples': 86, 'subsample': 0.9784162775586962, 'colsample_bytree': 0.6040871208188888}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:11:45,635] Trial 59 finished with value: 0.7759511873171985 and parameters: {'n_estimators': 781, 'learning_rate': 0.06331100140507459, 'num_leaves': 142, 'max_depth': 11, 'min_child_samples': 61, 'subsample': 0.8943759232751844, 'colsample_bytree': 0.8361624942258921}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:11:54,094] Trial 60 finished with value: 1.0942235447157207 and parameters: {'n_estimators': 727, 'learning_rate': 0.06471271791698865, 'num_leaves': 145, 'max_depth': 10, 'min_child_samples': 58, 'subsample': 0.9309048348025911, 'colsample_bytree': 0.808104611449347}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:12:02,157] Trial 61 finished with value: 1.7134692380289418 and parameters: {'n_estimators': 785, 'learning_rate': 0.03932501044342676, 'num_leaves': 135, 'max_depth': 11, 'min_child_samples': 72, 'subsample': 0.8267072715314473, 'colsample_bytree': 0.848586716644741}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:12:12,110] Trial 62 finished with value: 1.3858818609527581 and parameters: {'n_estimators': 687, 'learning_rate': 0.029998743350055684, 'num_leaves': 171, 'max_depth': 11, 'min_child_samples': 66, 'subsample': 0.8966800390332235, 'colsample_bytree': 0.876405084360426}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:12:20,731] Trial 63 finished with value: 1.4230306979778509 and parameters: {'n_estimators': 914, 'learning_rate': 0.058692388710631815, 'num_leaves': 119, 'max_depth': 12, 'min_child_samples': 61, 'subsample': 0.849745389414087, 'colsample_bytree': 0.8388060983875303}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:12:33,207] Trial 64 finished with value: 1.7591251926308562 and parameters: {'n_estimators': 819, 'learning_rate': 0.07325921608140815, 'num_leaves': 156, 'max_depth': 8, 'min_child_samples': 47, 'subsample': 0.7774018735913074, 'colsample_bytree': 0.8300875733503317}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:12:36,148] Trial 65 finished with value: 2.0897007118203192 and parameters: {'n_estimators': 772, 'learning_rate': 0.08404453834433194, 'num_leaves': 107, 'max_depth': 7, 'min_child_samples': 100, 'subsample': 0.8149964107021787, 'colsample_bytree': 0.8068822483956513}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:12:43,855] Trial 66 finished with value: 1.990923220159433 and parameters: {'n_estimators': 486, 'learning_rate': 0.02327162978260406, 'num_leaves': 84, 'max_depth': 10, 'min_child_samples': 54, 'subsample': 0.7477494719233576, 'colsample_bytree': 0.6724815132710613}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:12:51,531] Trial 67 finished with value: 2.4321384889836954 and parameters: {'n_estimators': 552, 'learning_rate': 0.043754040393045604, 'num_leaves': 130, 'max_depth': 11, 'min_child_samples': 75, 'subsample': 0.9218672271798578, 'colsample_bytree': 0.9705284339845186}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:12:55,700] Trial 68 finished with value: 1.6418661518544995 and parameters: {'n_estimators': 896, 'learning_rate': 0.14497295102395513, 'num_leaves': 69, 'max_depth': 9, 'min_child_samples': 56, 'subsample': 0.7967014499759798, 'colsample_bytree': 0.8582005218108694}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:02,179] Trial 69 finished with value: 1.067394090765236 and parameters: {'n_estimators': 624, 'learning_rate': 0.03516940870624759, 'num_leaves': 170, 'max_depth': 5, 'min_child_samples': 91, 'subsample': 0.8655874819371657, 'colsample_bytree': 0.8974806470466045}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:03,760] Trial 70 finished with value: 2.778420501090894 and parameters: {'n_estimators': 755, 'learning_rate': 0.29940869220227195, 'num_leaves': 123, 'max_depth': 8, 'min_child_samples': 97, 'subsample': 0.9813680715871811, 'colsample_bytree': 0.7511022206721223}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:05,121] Trial 71 finished with value: 1.9062913031292816 and parameters: {'n_estimators': 258, 'learning_rate': 0.23877715283524034, 'num_leaves': 93, 'max_depth': 5, 'min_child_samples': 88, 'subsample': 0.9507046541510626, 'colsample_bytree': 0.7131751750066295}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:06,471] Trial 72 finished with value: 4.981443851915946 and parameters: {'n_estimators': 439, 'learning_rate': 0.2086622849682167, 'num_leaves': 104, 'max_depth': 4, 'min_child_samples': 79, 'subsample': 0.7749397419409442, 'colsample_bytree': 0.6529528580336216}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:08,857] Trial 73 finished with value: 3.520960692026393 and parameters: {'n_estimators': 400, 'learning_rate': 0.18726111864121667, 'num_leaves': 48, 'max_depth': 4, 'min_child_samples': 94, 'subsample': 0.723443332507424, 'colsample_bytree': 0.7025141712252378}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:10,620] Trial 74 finished with value: 4.432201791218617 and parameters: {'n_estimators': 362, 'learning_rate': 0.22440238810205265, 'num_leaves': 89, 'max_depth': 6, 'min_child_samples': 68, 'subsample': 0.835814528383021, 'colsample_bytree': 0.7265052069832998}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:12,437] Trial 75 finished with value: 1.8990342180902782 and parameters: {'n_estimators': 251, 'learning_rate': 0.26604007380564354, 'num_leaves': 300, 'max_depth': 5, 'min_child_samples': 63, 'subsample': 0.8010939735702408, 'colsample_bytree': 0.6286653961704267}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:26,483] Trial 76 finished with value: 1.2526378101946885 and parameters: {'n_estimators': 966, 'learning_rate': 0.017724675155173307, 'num_leaves': 78, 'max_depth': 7, 'min_child_samples': 44, 'subsample': 0.8864146314496513, 'colsample_bytree': 0.6888131832022569}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:36,551] Trial 77 finished with value: 1.0034371787797811 and parameters: {'n_estimators': 802, 'learning_rate': 0.10014580328229422, 'num_leaves': 151, 'max_depth': 12, 'min_child_samples': 60, 'subsample': 0.752023209722569, 'colsample_bytree': 0.9818302928200296}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:41,388] Trial 78 finished with value: 1.4310766470028988 and parameters: {'n_estimators': 853, 'learning_rate': 0.05957165318079988, 'num_leaves': 33, 'max_depth': 6, 'min_child_samples': 91, 'subsample': 0.7025600436183222, 'colsample_bytree': 0.8851942843714923}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:44,407] Trial 79 finished with value: 0.8712714877092942 and parameters: {'n_estimators': 673, 'learning_rate': 0.05159025903980968, 'num_leaves': 290, 'max_depth': 3, 'min_child_samples': 81, 'subsample': 0.9373287794648755, 'colsample_bytree': 0.8674013867136199}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:49,048] Trial 80 finished with value: 0.8049855324096565 and parameters: {'n_estimators': 725, 'learning_rate': 0.04924428666227963, 'num_leaves': 283, 'max_depth': 3, 'min_child_samples': 81, 'subsample': 0.9392462399250012, 'colsample_bytree': 0.9209930838094046}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:53,752] Trial 81 finished with value: 0.9874883797504633 and parameters: {'n_estimators': 672, 'learning_rate': 0.0505443617547538, 'num_leaves': 291, 'max_depth': 3, 'min_child_samples': 82, 'subsample': 0.9434383819741466, 'colsample_bytree': 0.8681273266628754}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:13:56,918] Trial 82 finished with value: 1.365825277192189 and parameters: {'n_estimators': 730, 'learning_rate': 0.06739148036747408, 'num_leaves': 282, 'max_depth': 3, 'min_child_samples': 86, 'subsample': 0.9276369125544871, 'colsample_bytree': 0.9526675791083415}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:14:01,195] Trial 83 finished with value: 1.0524296624689558 and parameters: {'n_estimators': 617, 'learning_rate': 0.05484331876267831, 'num_leaves': 277, 'max_depth': 3, 'min_child_samples': 73, 'subsample': 0.9644955223907186, 'colsample_bytree': 0.9282525865949682}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:14:05,040] Trial 84 finished with value: 1.0979188002059597 and parameters: {'n_estimators': 700, 'learning_rate': 0.02842248207497557, 'num_leaves': 269, 'max_depth': 3, 'min_child_samples': 77, 'subsample': 0.9184756550160277, 'colsample_bytree': 0.9024486526744705}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:14:10,888] Trial 85 finished with value: 1.222769831515353 and parameters: {'n_estimators': 558, 'learning_rate': 0.046645403225417534, 'num_leaves': 260, 'max_depth': 9, 'min_child_samples': 85, 'subsample': 0.9342650932849367, 'colsample_bytree': 0.9192883734980781}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:14:16,244] Trial 86 finished with value: 0.9111686177038749 and parameters: {'n_estimators': 645, 'learning_rate': 0.013044864746653145, 'num_leaves': 291, 'max_depth': 4, 'min_child_samples': 81, 'subsample': 0.9842611013885204, 'colsample_bytree': 0.961211923027883}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:14:22,925] Trial 87 finished with value: 0.8354061077398199 and parameters: {'n_estimators': 644, 'learning_rate': 0.014680423658719364, 'num_leaves': 290, 'max_depth': 4, 'min_child_samples': 82, 'subsample': 0.990943339763092, 'colsample_bytree': 0.959432891826757}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:14:27,711] Trial 88 finished with value: 1.6407353931555868 and parameters: {'n_estimators': 611, 'learning_rate': 0.018148166092876443, 'num_leaves': 292, 'max_depth': 3, 'min_child_samples': 75, 'subsample': 0.9952765372643967, 'colsample_bytree': 0.9339298317367062}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:14:35,588] Trial 89 finished with value: 0.9485506011478995 and parameters: {'n_estimators': 647, 'learning_rate': 0.034162720135691535, 'num_leaves': 164, 'max_depth': 3, 'min_child_samples': 77, 'subsample': 0.9877546112748021, 'colsample_bytree': 0.9418247853864631}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:14:41,608] Trial 90 finished with value: 0.8890121923395101 and parameters: {'n_estimators': 680, 'learning_rate': 0.025212755494567037, 'num_leaves': 256, 'max_depth': 4, 'min_child_samples': 51, 'subsample': 0.9733634277180675, 'colsample_bytree': 0.9880381100888894}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:14:47,575] Trial 91 finished with value: 1.3704640590560486 and parameters: {'n_estimators': 675, 'learning_rate': 0.025834817016167456, 'num_leaves': 251, 'max_depth': 4, 'min_child_samples': 51, 'subsample': 0.961755989014685, 'colsample_bytree': 0.9843533418128676}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:14:56,807] Trial 92 finished with value: 2.0100576368066347 and parameters: {'n_estimators': 758, 'learning_rate': 0.010551104809975531, 'num_leaves': 284, 'max_depth': 4, 'min_child_samples': 48, 'subsample': 0.952051783342179, 'colsample_bytree': 0.9747829720739087}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:15:01,639] Trial 93 finished with value: 0.772849539416407 and parameters: {'n_estimators': 717, 'learning_rate': 0.04000502841901274, 'num_leaves': 237, 'max_depth': 4, 'min_child_samples': 89, 'subsample': 0.9709159974785864, 'colsample_bytree': 0.996952922181819}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:15:06,682] Trial 94 finished with value: 1.477372786030926 and parameters: {'n_estimators': 713, 'learning_rate': 0.038425031499629385, 'num_leaves': 239, 'max_depth': 3, 'min_child_samples': 96, 'subsample': 0.9009996212656447, 'colsample_bytree': 0.9985134313224022}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:15:11,710] Trial 95 finished with value: 1.1452223985750893 and parameters: {'n_estimators': 735, 'learning_rate': 0.04359768382276439, 'num_leaves': 207, 'max_depth': 5, 'min_child_samples': 90, 'subsample': 0.9732142493607993, 'colsample_bytree': 0.9647822292453282}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:15:17,126] Trial 96 finished with value: 1.3686463328212406 and parameters: {'n_estimators': 785, 'learning_rate': 0.03500822095047599, 'num_leaves': 272, 'max_depth': 4, 'min_child_samples': 93, 'subsample': 0.9984553159107761, 'colsample_bytree': 0.9524184287546921}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:15:22,183] Trial 97 finished with value: 0.9776183310043184 and parameters: {'n_estimators': 705, 'learning_rate': 0.057354412705539634, 'num_leaves': 229, 'max_depth': 8, 'min_child_samples': 87, 'subsample': 0.9574240582617088, 'colsample_bytree': 0.9080972062426409}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:15:25,798] Trial 98 finished with value: 0.7728473126168703 and parameters: {'n_estimators': 599, 'learning_rate': 0.01903570747062011, 'num_leaves': 296, 'max_depth': 3, 'min_child_samples': 83, 'subsample': 0.940852297298726, 'colsample_bytree': 0.9738317530657992}. Best is trial 27 with value: 0.664480119895121.
# [I 2025-07-18 08:15:39,227] Trial 99 finished with value: 0.7655319096506809 and parameters: {'n_estimators': 816, 'learning_rate': 0.01758371368292637, 'num_leaves': 297, 'max_depth': 7, 'min_child_samples': 83, 'subsample': 0.6423151737530357, 'colsample_bytree': 0.9767923592060571}. Best is trial 27 with value: 0.664480119895121.
# BEST MAPE FOR BlendProperty1: 0.664480119895121
# BEST HYPERPARAMETERS FOR BlendProperty1: {'n_estimators': 777, 'learning_rate': 0.1476886594008643, 'num_leaves': 92, 'max_depth': 8, 'min_child_samples': 88, 'subsample': 0.8156123302508664, 'colsample_bytree': 0.9540732789631515}
# [I 2025-07-18 08:15:41,499] A new study created in RDB with name: lightgbm-tuning-BlendProperty2
# Saved best model for BlendProperty1
#
# --- TUNING AND TRAINING FOR BlendProperty2 ---
# [I 2025-07-18 08:15:46,943] Trial 0 finished with value: 0.7790544240928472 and parameters: {'n_estimators': 496, 'learning_rate': 0.021174372223544416, 'num_leaves': 201, 'max_depth': 9, 'min_child_samples': 99, 'subsample': 0.8633953518903468, 'colsample_bytree': 0.8854164751502047}. Best is trial 0 with value: 0.7790544240928472.
# [I 2025-07-18 08:15:50,260] Trial 1 finished with value: 0.7002564843102212 and parameters: {'n_estimators': 470, 'learning_rate': 0.09398685441847866, 'num_leaves': 99, 'max_depth': 5, 'min_child_samples': 77, 'subsample': 0.7160273776846018, 'colsample_bytree': 0.8184718459357181}. Best is trial 1 with value: 0.7002564843102212.
# [I 2025-07-18 08:15:51,918] Trial 2 finished with value: 0.9116071774318557 and parameters: {'n_estimators': 281, 'learning_rate': 0.1590666010295683, 'num_leaves': 183, 'max_depth': 3, 'min_child_samples': 45, 'subsample': 0.9018057216117575, 'colsample_bytree': 0.9235831914679075}. Best is trial 1 with value: 0.7002564843102212.
# [I 2025-07-18 08:15:55,382] Trial 3 finished with value: 0.9167704749071142 and parameters: {'n_estimators': 503, 'learning_rate': 0.12971921456953459, 'num_leaves': 23, 'max_depth': 6, 'min_child_samples': 42, 'subsample': 0.6396936016739457, 'colsample_bytree': 0.8430287828459382}. Best is trial 1 with value: 0.7002564843102212.
# [I 2025-07-18 08:15:59,146] Trial 4 finished with value: 0.7894419489324894 and parameters: {'n_estimators': 358, 'learning_rate': 0.08093138826521541, 'num_leaves': 196, 'max_depth': 5, 'min_child_samples': 57, 'subsample': 0.8686244898786989, 'colsample_bytree': 0.9690803405559006}. Best is trial 1 with value: 0.7002564843102212.
# [I 2025-07-18 08:16:20,083] Trial 5 finished with value: 0.7539976280749008 and parameters: {'n_estimators': 770, 'learning_rate': 0.05955905048458973, 'num_leaves': 212, 'max_depth': 10, 'min_child_samples': 12, 'subsample': 0.7349580712264677, 'colsample_bytree': 0.6650861966210436}. Best is trial 1 with value: 0.7002564843102212.
# [I 2025-07-18 08:16:21,758] Trial 6 finished with value: 1.1883294328985028 and parameters: {'n_estimators': 193, 'learning_rate': 0.26626553643179046, 'num_leaves': 28, 'max_depth': 8, 'min_child_samples': 66, 'subsample': 0.8255681666790954, 'colsample_bytree': 0.8437006260932559}. Best is trial 1 with value: 0.7002564843102212.
# [I 2025-07-18 08:16:23,985] Trial 7 finished with value: 0.9616769632353345 and parameters: {'n_estimators': 768, 'learning_rate': 0.2131395721442962, 'num_leaves': 56, 'max_depth': 10, 'min_child_samples': 88, 'subsample': 0.9375748117791429, 'colsample_bytree': 0.6682265599254225}. Best is trial 1 with value: 0.7002564843102212.
# [I 2025-07-18 08:16:25,842] Trial 8 finished with value: 0.9457048283297734 and parameters: {'n_estimators': 456, 'learning_rate': 0.11371722690737106, 'num_leaves': 186, 'max_depth': 3, 'min_child_samples': 54, 'subsample': 0.9784755024703892, 'colsample_bytree': 0.739083490929721}. Best is trial 1 with value: 0.7002564843102212.
# [I 2025-07-18 08:16:27,786] Trial 9 finished with value: 0.6918992588464434 and parameters: {'n_estimators': 605, 'learning_rate': 0.13936502254309543, 'num_leaves': 271, 'max_depth': 4, 'min_child_samples': 43, 'subsample': 0.9057015594710034, 'colsample_bytree': 0.7641030641901312}. Best is trial 9 with value: 0.6918992588464434.
# [I 2025-07-18 08:16:38,098] Trial 10 finished with value: 1.0258379476616033 and parameters: {'n_estimators': 900, 'learning_rate': 0.18694500689597204, 'num_leaves': 293, 'max_depth': 12, 'min_child_samples': 19, 'subsample': 0.7749407661960731, 'colsample_bytree': 0.7515114234887357}. Best is trial 9 with value: 0.6918992588464434.
# [I 2025-07-18 08:16:42,314] Trial 11 finished with value: 0.7876118307714519 and parameters: {'n_estimators': 663, 'learning_rate': 0.08656342757785532, 'num_leaves': 107, 'max_depth': 5, 'min_child_samples': 78, 'subsample': 0.6848909718214266, 'colsample_bytree': 0.7701594018033192}. Best is trial 9 with value: 0.6918992588464434.
# [I 2025-07-18 08:16:53,273] Trial 12 finished with value: 0.6614725397232118 and parameters: {'n_estimators': 633, 'learning_rate': 0.013820025818564063, 'num_leaves': 286, 'max_depth': 6, 'min_child_samples': 33, 'subsample': 0.7363696050640641, 'colsample_bytree': 0.8122282307988858}. Best is trial 12 with value: 0.6614725397232118.
# [I 2025-07-18 08:17:04,143] Trial 13 finished with value: 0.6253422949907094 and parameters: {'n_estimators': 653, 'learning_rate': 0.026447569426299892, 'num_leaves': 299, 'max_depth': 7, 'min_child_samples': 29, 'subsample': 0.7928659748622204, 'colsample_bytree': 0.6056699117085322}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:17:19,909] Trial 14 finished with value: 0.7086108336822049 and parameters: {'n_estimators': 924, 'learning_rate': 0.03262614118326217, 'num_leaves': 256, 'max_depth': 7, 'min_child_samples': 26, 'subsample': 0.7883737851428819, 'colsample_bytree': 0.602072189550536}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:17:38,109] Trial 15 finished with value: 0.6365404470288396 and parameters: {'n_estimators': 716, 'learning_rate': 0.014906806904491685, 'num_leaves': 243, 'max_depth': 7, 'min_child_samples': 27, 'subsample': 0.6111231722416539, 'colsample_bytree': 0.6885299350376286}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:18:00,545] Trial 16 finished with value: 0.857631890658346 and parameters: {'n_estimators': 813, 'learning_rate': 0.05239540169992654, 'num_leaves': 243, 'max_depth': 8, 'min_child_samples': 9, 'subsample': 0.6354285892670506, 'colsample_bytree': 0.6046722281777795}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:18:02,984] Trial 17 finished with value: 0.9402801812131203 and parameters: {'n_estimators': 983, 'learning_rate': 0.2658465326015341, 'num_leaves': 234, 'max_depth': 7, 'min_child_samples': 31, 'subsample': 0.6122272747630152, 'colsample_bytree': 0.6803841556268537}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:18:19,509] Trial 18 finished with value: 0.8348517491470684 and parameters: {'n_estimators': 695, 'learning_rate': 0.05137735637917478, 'num_leaves': 147, 'max_depth': 9, 'min_child_samples': 21, 'subsample': 0.6821618527077337, 'colsample_bytree': 0.6350360938760731}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:18:22,837] Trial 19 finished with value: 1.0484358163919185 and parameters: {'n_estimators': 851, 'learning_rate': 0.22779194912347517, 'num_leaves': 297, 'max_depth': 6, 'min_child_samples': 5, 'subsample': 0.8219556821553274, 'colsample_bytree': 0.7133507894758639}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:18:25,365] Trial 20 finished with value: 1.026790533854225 and parameters: {'n_estimators': 718, 'learning_rate': 0.2929648082487112, 'num_leaves': 229, 'max_depth': 11, 'min_child_samples': 36, 'subsample': 0.9932761916934989, 'colsample_bytree': 0.706840161096028}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:18:38,154] Trial 21 finished with value: 0.7139130946409812 and parameters: {'n_estimators': 594, 'learning_rate': 0.015160298474982514, 'num_leaves': 271, 'max_depth': 6, 'min_child_samples': 30, 'subsample': 0.7477795275753563, 'colsample_bytree': 0.6290570318449785}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:18:56,730] Trial 22 finished with value: 0.6902633082053617 and parameters: {'n_estimators': 625, 'learning_rate': 0.012799726592791503, 'num_leaves': 276, 'max_depth': 7, 'min_child_samples': 20, 'subsample': 0.6858053092590699, 'colsample_bytree': 0.792726682241075}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:19:07,873] Trial 23 finished with value: 0.6907078647906435 and parameters: {'n_estimators': 553, 'learning_rate': 0.04330645712238865, 'num_leaves': 292, 'max_depth': 8, 'min_child_samples': 37, 'subsample': 0.76028418488188, 'colsample_bytree': 0.709946333329185}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:19:14,969] Trial 24 finished with value: 0.6306521389275652 and parameters: {'n_estimators': 713, 'learning_rate': 0.07159620038085686, 'num_leaves': 254, 'max_depth': 6, 'min_child_samples': 49, 'subsample': 0.6007692193092912, 'colsample_bytree': 0.8806648806651364}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:19:18,081] Trial 25 finished with value: 0.7823330994723092 and parameters: {'n_estimators': 761, 'learning_rate': 0.07656067591728163, 'num_leaves': 150, 'max_depth': 4, 'min_child_samples': 49, 'subsample': 0.6150661761758024, 'colsample_bytree': 0.896845122890557}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:19:23,740] Trial 26 finished with value: 0.720371998783756 and parameters: {'n_estimators': 366, 'learning_rate': 0.10276589187161822, 'num_leaves': 249, 'max_depth': 9, 'min_child_samples': 64, 'subsample': 0.6572813727332099, 'colsample_bytree': 0.9752580643531863}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:19:33,712] Trial 27 finished with value: 0.8145668681959244 and parameters: {'n_estimators': 846, 'learning_rate': 0.06591408640186891, 'num_leaves': 220, 'max_depth': 7, 'min_child_samples': 61, 'subsample': 0.6029919462724658, 'colsample_bytree': 0.646885065624252}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:19:45,016] Trial 28 finished with value: 0.6694618406853118 and parameters: {'n_estimators': 714, 'learning_rate': 0.037426491807817125, 'num_leaves': 259, 'max_depth': 5, 'min_child_samples': 15, 'subsample': 0.6646822447540974, 'colsample_bytree': 0.9342635160461545}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:19:59,534] Trial 29 finished with value: 0.66897713976178 and parameters: {'n_estimators': 510, 'learning_rate': 0.02896241930855599, 'num_leaves': 209, 'max_depth': 8, 'min_child_samples': 24, 'subsample': 0.708842265211577, 'colsample_bytree': 0.8936216611206552}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:20:01,634] Trial 30 finished with value: 0.7761465085649087 and parameters: {'n_estimators': 566, 'learning_rate': 0.11718161243288062, 'num_leaves': 178, 'max_depth': 4, 'min_child_samples': 49, 'subsample': 0.8326629801000183, 'colsample_bytree': 0.8657270541040407}. Best is trial 13 with value: 0.6253422949907094.
# [I 2025-07-18 08:20:13,628] Trial 31 finished with value: 0.6201367202255759 and parameters: {'n_estimators': 653, 'learning_rate': 0.026168258234385566, 'num_leaves': 278, 'max_depth': 6, 'min_child_samples': 35, 'subsample': 0.6364846642328715, 'colsample_bytree': 0.8079853537869403}. Best is trial 31 with value: 0.6201367202255759.
# [I 2025-07-18 08:20:19,217] Trial 32 finished with value: 0.8284018077365161 and parameters: {'n_estimators': 680, 'learning_rate': 0.031648614355759656, 'num_leaves': 269, 'max_depth': 6, 'min_child_samples': 100, 'subsample': 0.6386545667262712, 'colsample_bytree': 0.8448169717323037}. Best is trial 31 with value: 0.6201367202255759.
# [I 2025-07-18 08:20:25,278] Trial 33 finished with value: 0.5900549855027382 and parameters: {'n_estimators': 422, 'learning_rate': 0.06403131398252673, 'num_leaves': 251, 'max_depth': 7, 'min_child_samples': 40, 'subsample': 0.6029801288457345, 'colsample_bytree': 0.7980582063868619}. Best is trial 33 with value: 0.5900549855027382.
# [I 2025-07-18 08:20:30,169] Trial 34 finished with value: 0.7929973204356416 and parameters: {'n_estimators': 403, 'learning_rate': 0.06439671985259138, 'num_leaves': 278, 'max_depth': 5, 'min_child_samples': 41, 'subsample': 0.7103303487544634, 'colsample_bytree': 0.7905005450838898}. Best is trial 33 with value: 0.5900549855027382.
# [I 2025-07-18 08:20:35,721] Trial 35 finished with value: 0.6405827972958795 and parameters: {'n_estimators': 263, 'learning_rate': 0.08812191580970802, 'num_leaves': 299, 'max_depth': 6, 'min_child_samples': 49, 'subsample': 0.6555346647095897, 'colsample_bytree': 0.9377193786681736}. Best is trial 33 with value: 0.5900549855027382.
# [I 2025-07-18 08:20:39,712] Trial 36 finished with value: 0.7553511434941325 and parameters: {'n_estimators': 447, 'learning_rate': 0.07127694265109427, 'num_leaves': 258, 'max_depth': 5, 'min_child_samples': 71, 'subsample': 0.6294429993884612, 'colsample_bytree': 0.8696069017891371}. Best is trial 33 with value: 0.5900549855027382.
# [I 2025-07-18 08:20:43,177] Trial 37 finished with value: 0.7880354528499416 and parameters: {'n_estimators': 516, 'learning_rate': 0.15076223666651006, 'num_leaves': 116, 'max_depth': 7, 'min_child_samples': 39, 'subsample': 0.666739111517432, 'colsample_bytree': 0.9026641249755457}. Best is trial 33 with value: 0.5900549855027382.
# [I 2025-07-18 08:20:45,403] Trial 38 finished with value: 0.9489322867186315 and parameters: {'n_estimators': 101, 'learning_rate': 0.17382460661446197, 'num_leaves': 226, 'max_depth': 8, 'min_child_samples': 57, 'subsample': 0.855814477890058, 'colsample_bytree': 0.9504284983607506}. Best is trial 33 with value: 0.5900549855027382.
# [I 2025-07-18 08:20:50,431] Trial 39 finished with value: 0.7786302004439538 and parameters: {'n_estimators': 304, 'learning_rate': 0.0997528120237135, 'num_leaves': 169, 'max_depth': 9, 'min_child_samples': 47, 'subsample': 0.6015575242986302, 'colsample_bytree': 0.8323790467173681}. Best is trial 33 with value: 0.5900549855027382.
# [I 2025-07-18 08:20:56,508] Trial 40 finished with value: 0.7438214001480421 and parameters: {'n_estimators': 410, 'learning_rate': 0.04857655183180483, 'num_leaves': 201, 'max_depth': 6, 'min_child_samples': 35, 'subsample': 0.9008780559714511, 'colsample_bytree': 0.8166901978529458}. Best is trial 33 with value: 0.5900549855027382.
# ...
# [I 2025-07-18 10:10:17,093] Trial 54 finished with value: 0.5265770860025167 and parameters: {'n_estimators': 950, 'learning_rate': 0.03215983351245588, 'num_leaves': 270, 'max_depth': 9, 'min_child_samples': 37, 'subsample': 0.6325800862320231, 'colsample_bytree': 0.7989588132943193}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:10:49,497] Trial 55 finished with value: 0.5365656046048101 and parameters: {'n_estimators': 828, 'learning_rate': 0.01876591685979517, 'num_leaves': 300, 'max_depth': 11, 'min_child_samples': 26, 'subsample': 0.6635150641051015, 'colsample_bytree': 0.8864705442931896}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:11:00,846] Trial 56 finished with value: 0.557487725343975 and parameters: {'n_estimators': 707, 'learning_rate': 0.05251055898351131, 'num_leaves': 254, 'max_depth': 9, 'min_child_samples': 33, 'subsample': 0.6433489818635313, 'colsample_bytree': 0.8428876619526705}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:11:16,450] Trial 57 finished with value: 0.5791243610560632 and parameters: {'n_estimators': 925, 'learning_rate': 0.07168792837723073, 'num_leaves': 278, 'max_depth': 10, 'min_child_samples': 22, 'subsample': 0.6135151693713918, 'colsample_bytree': 0.7689667040021}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:11:26,244] Trial 58 finished with value: 0.5988493022484876 and parameters: {'n_estimators': 878, 'learning_rate': 0.037633723659299956, 'num_leaves': 291, 'max_depth': 11, 'min_child_samples': 59, 'subsample': 0.6791159434566859, 'colsample_bytree': 0.6935563344392207}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:11:33,814] Trial 59 finished with value: 0.8970385875660118 and parameters: {'n_estimators': 774, 'learning_rate': 0.29902344975623185, 'num_leaves': 266, 'max_depth': 9, 'min_child_samples': 15, 'subsample': 0.6001053059144593, 'colsample_bytree': 0.8086350797746957}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:11:53,611] Trial 60 finished with value: 0.5044723406203344 and parameters: {'n_estimators': 969, 'learning_rate': 0.021812368649063628, 'num_leaves': 280, 'max_depth': 8, 'min_child_samples': 40, 'subsample': 0.6284603874649708, 'colsample_bytree': 0.6845747897891468}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:12:09,038] Trial 61 finished with value: 0.47098187638646144 and parameters: {'n_estimators': 967, 'learning_rate': 0.0178442687901369, 'num_leaves': 282, 'max_depth': 8, 'min_child_samples': 41, 'subsample': 0.6259324592729532, 'colsample_bytree': 0.6703109361021741}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:12:23,034] Trial 62 finished with value: 0.530121821907881 and parameters: {'n_estimators': 974, 'learning_rate': 0.03264308143320762, 'num_leaves': 275, 'max_depth': 8, 'min_child_samples': 41, 'subsample': 0.6520117023039401, 'colsample_bytree': 0.6705319636397695}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:12:40,061] Trial 63 finished with value: 0.4962192409681639 and parameters: {'n_estimators': 928, 'learning_rate': 0.016572077286588105, 'num_leaves': 292, 'max_depth': 8, 'min_child_samples': 48, 'subsample': 0.6298848555057486, 'colsample_bytree': 0.6470295519074339}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:12:43,139] Trial 64 finished with value: 0.6635243862683937 and parameters: {'n_estimators': 928, 'learning_rate': 0.15651929761103234, 'num_leaves': 291, 'max_depth': 8, 'min_child_samples': 54, 'subsample': 0.6162831145401801, 'colsample_bytree': 0.6369318081643972}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:12:51,482] Trial 65 finished with value: 0.5254101330811679 and parameters: {'n_estimators': 983, 'learning_rate': 0.0452737004590803, 'num_leaves': 251, 'max_depth': 7, 'min_child_samples': 47, 'subsample': 0.6389921796827873, 'colsample_bytree': 0.6151341321298603}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:12:53,794] Trial 66 finished with value: 0.9104590894566839 and parameters: {'n_estimators': 918, 'learning_rate': 0.2605195686294947, 'num_leaves': 264, 'max_depth': 6, 'min_child_samples': 37, 'subsample': 0.6989659861416234, 'colsample_bytree': 0.6461537383050299}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:13:05,459] Trial 67 finished with value: 0.5156575160506157 and parameters: {'n_estimators': 675, 'learning_rate': 0.016292197669299204, 'num_leaves': 295, 'max_depth': 10, 'min_child_samples': 50, 'subsample': 0.6673962967085868, 'colsample_bytree': 0.7118532978629452}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:13:11,180] Trial 68 finished with value: 0.5199022938147053 and parameters: {'n_estimators': 999, 'learning_rate': 0.06091292304421161, 'num_leaves': 76, 'max_depth': 9, 'min_child_samples': 64, 'subsample': 0.6239391324146126, 'colsample_bytree': 0.7317779059157051}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:13:13,790] Trial 69 finished with value: 0.7332303666663949 and parameters: {'n_estimators': 797, 'learning_rate': 0.18270453245131638, 'num_leaves': 277, 'max_depth': 8, 'min_child_samples': 72, 'subsample': 0.6856737067693248, 'colsample_bytree': 0.6761120157822508}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:13:27,778] Trial 70 finished with value: 0.5037437785270092 and parameters: {'n_estimators': 834, 'learning_rate': 0.028486473947930795, 'num_leaves': 295, 'max_depth': 7, 'min_child_samples': 30, 'subsample': 0.6558696466951209, 'colsample_bytree': 0.658171950029692}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:13:44,294] Trial 71 finished with value: 0.4853212336019969 and parameters: {'n_estimators': 890, 'learning_rate': 0.02960346873573204, 'num_leaves': 299, 'max_depth': 7, 'min_child_samples': 29, 'subsample': 0.6571654674636576, 'colsample_bytree': 0.6491528883165416}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:14:00,114] Trial 72 finished with value: 0.5263747544457356 and parameters: {'n_estimators': 892, 'learning_rate': 0.017254150014896465, 'num_leaves': 299, 'max_depth': 8, 'min_child_samples': 35, 'subsample': 0.7396574266690095, 'colsample_bytree': 0.6488042731522344}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:14:11,023] Trial 73 finished with value: 0.5273571229898941 and parameters: {'n_estimators': 761, 'learning_rate': 0.010419548748539531, 'num_leaves': 285, 'max_depth': 7, 'min_child_samples': 44, 'subsample': 0.6432270635193795, 'colsample_bytree': 0.6010498914290237}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:14:27,220] Trial 74 finished with value: 0.5220597937842633 and parameters: {'n_estimators': 937, 'learning_rate': 0.03840763628809678, 'num_leaves': 271, 'max_depth': 9, 'min_child_samples': 42, 'subsample': 0.6135769475408765, 'colsample_bytree': 0.6833625781541294}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:14:45,851] Trial 75 finished with value: 0.5186132597517698 and parameters: {'n_estimators': 855, 'learning_rate': 0.029557714582604484, 'num_leaves': 291, 'max_depth': 8, 'min_child_samples': 31, 'subsample': 0.6305689393856816, 'colsample_bytree': 0.6186599028676274}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:14:54,043] Trial 76 finished with value: 0.525400743474904 and parameters: {'n_estimators': 898, 'learning_rate': 0.04826199259718282, 'num_leaves': 259, 'max_depth': 7, 'min_child_samples': 53, 'subsample': 0.706680526489313, 'colsample_bytree': 0.6382681303163045}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:15:04,087] Trial 77 finished with value: 0.5077782824619467 and parameters: {'n_estimators': 718, 'learning_rate': 0.05456451688712931, 'num_leaves': 281, 'max_depth': 9, 'min_child_samples': 38, 'subsample': 0.67207528308571, 'colsample_bytree': 0.6638432797949737}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:15:06,844] Trial 78 finished with value: 0.7267152870290999 and parameters: {'n_estimators': 821, 'learning_rate': 0.22638497064817373, 'num_leaves': 145, 'max_depth': 10, 'min_child_samples': 58, 'subsample': 0.8191844205521392, 'colsample_bytree': 0.706897914914675}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:15:12,198] Trial 79 finished with value: 0.5496729694470404 and parameters: {'n_estimators': 477, 'learning_rate': 0.01976286265288968, 'num_leaves': 270, 'max_depth': 5, 'min_child_samples': 47, 'subsample': 0.6114750585798432, 'colsample_bytree': 0.6913825357161334}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:15:24,402] Trial 80 finished with value: 0.5259871017569948 and parameters: {'n_estimators': 960, 'learning_rate': 0.03984938566321068, 'num_leaves': 300, 'max_depth': 8, 'min_child_samples': 34, 'subsample': 0.6520466056570632, 'colsample_bytree': 0.7268387303146812}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:15:45,391] Trial 81 finished with value: 0.4961600719065246 and parameters: {'n_estimators': 793, 'learning_rate': 0.027622073281905954, 'num_leaves': 293, 'max_depth': 7, 'min_child_samples': 29, 'subsample': 0.659982216793432, 'colsample_bytree': 0.6626178424364385}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:15:59,829] Trial 82 finished with value: 0.5692725185873359 and parameters: {'n_estimators': 787, 'learning_rate': 0.025679646715310315, 'num_leaves': 283, 'max_depth': 7, 'min_child_samples': 28, 'subsample': 0.6334719137063968, 'colsample_bytree': 0.6551500618408085}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:16:12,235] Trial 83 finished with value: 0.5008602896700196 and parameters: {'n_estimators': 742, 'learning_rate': 0.015611233793302988, 'num_leaves': 292, 'max_depth': 7, 'min_child_samples': 36, 'subsample': 0.6215950686397657, 'colsample_bytree': 0.676192711361317}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:16:20,655] Trial 84 finished with value: 0.5072708710109362 and parameters: {'n_estimators': 737, 'learning_rate': 0.03268117294226561, 'num_leaves': 292, 'max_depth': 6, 'min_child_samples': 36, 'subsample': 0.6607518623382396, 'colsample_bytree': 0.6288154085010391}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:16:27,944] Trial 85 finished with value: 0.5283213760267809 and parameters: {'n_estimators': 849, 'learning_rate': 0.06639792009569254, 'num_leaves': 275, 'max_depth': 7, 'min_child_samples': 40, 'subsample': 0.6207226271857396, 'colsample_bytree': 0.644348378548487}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:16:41,752] Trial 86 finished with value: 0.5250316759318899 and parameters: {'n_estimators': 648, 'learning_rate': 0.015123465428104032, 'num_leaves': 263, 'max_depth': 6, 'min_child_samples': 32, 'subsample': 0.6499833118018522, 'colsample_bytree': 0.6737232182138266}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:16:52,496] Trial 87 finished with value: 0.47739444763023087 and parameters: {'n_estimators': 688, 'learning_rate': 0.027188237289900066, 'num_leaves': 284, 'max_depth': 6, 'min_child_samples': 23, 'subsample': 0.6377903224870424, 'colsample_bytree': 0.6976046570807214}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:17:05,540] Trial 88 finished with value: 0.49552060156702427 and parameters: {'n_estimators': 687, 'learning_rate': 0.025800433284937543, 'num_leaves': 286, 'max_depth': 6, 'min_child_samples': 17, 'subsample': 0.681068884361832, 'colsample_bytree': 0.6596779699756578}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:17:12,855] Trial 89 finished with value: 0.5878992477476197 and parameters: {'n_estimators': 674, 'learning_rate': 0.04269042229703226, 'num_leaves': 249, 'max_depth': 5, 'min_child_samples': 19, 'subsample': 0.6859690137797799, 'colsample_bytree': 0.6098628608506906}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:17:23,347] Trial 90 finished with value: 0.6020725866879324 and parameters: {'n_estimators': 691, 'learning_rate': 0.05210109891904843, 'num_leaves': 283, 'max_depth': 6, 'min_child_samples': 10, 'subsample': 0.6737842543222227, 'colsample_bytree': 0.6990272986802436}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:17:37,098] Trial 91 finished with value: 0.5451334504242022 and parameters: {'n_estimators': 626, 'learning_rate': 0.027147601297952115, 'num_leaves': 286, 'max_depth': 6, 'min_child_samples': 22, 'subsample': 0.6638654951435682, 'colsample_bytree': 0.6639536419628724}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:17:51,801] Trial 92 finished with value: 0.5795896972735981 and parameters: {'n_estimators': 580, 'learning_rate': 0.016898694959621686, 'num_leaves': 293, 'max_depth': 7, 'min_child_samples': 28, 'subsample': 0.7159695240672295, 'colsample_bytree': 0.9735668409956708}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:17:55,680] Trial 93 finished with value: 0.5555918014982426 and parameters: {'n_estimators': 530, 'learning_rate': 0.02407283483820185, 'num_leaves': 276, 'max_depth': 5, 'min_child_samples': 99, 'subsample': 0.6434122194840858, 'colsample_bytree': 0.6488899991426982}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:18:07,790] Trial 94 finished with value: 0.5358856305031416 and parameters: {'n_estimators': 727, 'learning_rate': 0.03443806601140027, 'num_leaves': 267, 'max_depth': 6, 'min_child_samples': 17, 'subsample': 0.6923655226734057, 'colsample_bytree': 0.6300862921736113}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:18:13,315] Trial 95 finished with value: 0.6031915212277181 and parameters: {'n_estimators': 756, 'learning_rate': 0.09253092860875149, 'num_leaves': 295, 'max_depth': 6, 'min_child_samples': 24, 'subsample': 0.6330165327797364, 'colsample_bytree': 0.6777589675693952}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:18:20,587] Trial 96 finished with value: 0.5616525971590939 and parameters: {'n_estimators': 798, 'learning_rate': 0.01013713601665284, 'num_leaves': 286, 'max_depth': 4, 'min_child_samples': 15, 'subsample': 0.9266018137420013, 'colsample_bytree': 0.6583054417938242}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:18:39,859] Trial 97 finished with value: 0.581203233538943 and parameters: {'n_estimators': 878, 'learning_rate': 0.04162594725759815, 'num_leaves': 239, 'max_depth': 7, 'min_child_samples': 22, 'subsample': 0.7010732004224508, 'colsample_bytree': 0.6863659515710105}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:18:54,559] Trial 98 finished with value: 0.6298866699550512 and parameters: {'n_estimators': 695, 'learning_rate': 0.03313540874411885, 'num_leaves': 258, 'max_depth': 7, 'min_child_samples': 20, 'subsample': 0.6812594790902731, 'colsample_bytree': 0.7130329892727838}. Best is trial 15 with value: 0.46134439195188753.
# [I 2025-07-18 10:19:06,763] Trial 99 finished with value: 0.6209263519669206 and parameters: {'n_estimators': 410, 'learning_rate': 0.019836678507891684, 'num_leaves': 184, 'max_depth': 6, 'min_child_samples': 5, 'subsample': 0.6249205049798718, 'colsample_bytree': 0.7392015939742163}. Best is trial 15 with value: 0.46134439195188753.
# BEST MAPE FOR BlendProperty10: 0.46134439195188753
# BEST HYPERPARAMETERS FOR BlendProperty10: {'n_estimators': 806, 'learning_rate': 0.06879826060990206, 'num_leaves': 263, 'max_depth': 10, 'min_child_samples': 60, 'subsample': 0.711751289956135, 'colsample_bytree': 0.6671329498719161}
# Saved best model for BlendProperty10

# %% [markdown]
# ### 3. List the Best Models with MAPE Scores

# %%
print("--- BEST MODELS AND MAPE SCORES ---\n")
for target, (model, mape) in best_models.items():
    print(f"{target}: MAPE = {mape:.4f}, Model = {model}")
print("--- ALL MODELS SAVED TO DISK ---\n")
print(f"Models are saved in: {model_dir}")
print(f"Optuna studies are saved in: {optuna_dir}")
# Out:
# --- BEST MODELS AND MAPE SCORES ---
# BlendProperty1: MAPE = 0.6645, Model = LGBMRegressor(colsample_bytree=0.9540732789631515,
#               learning_rate=0.1476886594008643, max_depth=8,
#               min_child_samples=88, n_estimators=777, n_jobs=-1, num_leaves=92,
#               random_state=42, subsample=0.8156123302508664)
# BlendProperty2: MAPE = 0.5901, Model = LGBMRegressor(colsample_bytree=0.7980582063868619,
#               learning_rate=0.06403131398252673, max_depth=7,
#               min_child_samples=40, n_estimators=422, n_jobs=-1, num_leaves=251,
#               random_state=42, subsample=0.6029801288457345)
# BlendProperty3: MAPE = 0.9523, Model = LGBMRegressor(colsample_bytree=0.7779508951042512,
#               learning_rate=0.05780234131412661, max_depth=8,
#               min_child_samples=47, n_estimators=593, n_jobs=-1, num_leaves=248,
#               random_state=42, subsample=0.853102339382838)
# BlendProperty4: MAPE = 0.5983, Model = LGBMRegressor(colsample_bytree=0.7279981192117051,
#               learning_rate=0.015333192596856584, max_depth=8,
#               min_child_samples=83, n_estimators=811, n_jobs=-1, num_leaves=105,
#               random_state=42, subsample=0.7824945556992893)
# BlendProperty5: MAPE = 0.1365, Model = LGBMRegressor(colsample_bytree=0.98434695824643,
#               learning_rate=0.020176686978292724, max_depth=6,
#               min_child_samples=9, n_estimators=856, n_jobs=-1, num_leaves=114,
#               random_state=42, subsample=0.6452235372463412)
# BlendProperty6: MAPE = 0.4947, Model = LGBMRegressor(colsample_bytree=0.6323888114760962,
#               learning_rate=0.02751790371293122, max_depth=12,
#               min_child_samples=28, n_estimators=536, n_jobs=-1, num_leaves=166,
#               random_state=42, subsample=0.8656252803882962)
# BlendProperty7: MAPE = 0.9001, Model = LGBMRegressor(colsample_bytree=0.7160976574352571,
#               learning_rate=0.09127338726168102, max_depth=10,
#               min_child_samples=31, n_estimators=370, n_jobs=-1, num_leaves=294,
#               random_state=42, subsample=0.8343089460743401)
# BlendProperty8: MAPE = 0.7446, Model = LGBMRegressor(colsample_bytree=0.8026588642390511,
#               learning_rate=0.026614042856997554, max_depth=9,
#               min_child_samples=22, n_estimators=289, n_jobs=-1, num_leaves=295,
#               random_state=42, subsample=0.9584896842282827)
# BlendProperty9: MAPE = 0.9503, Model = LGBMRegressor(colsample_bytree=0.7169081452240404,
#               learning_rate=0.0712565290381967, max_depth=9,
#               min_child_samples=48, n_estimators=657, n_jobs=-1, num_leaves=227,
#               random_state=42, subsample=0.9890307391233176)
# BlendProperty10: MAPE = 0.4613, Model = LGBMRegressor(colsample_bytree=0.6671329498719161,
#               learning_rate=0.06879826060990206, max_depth=10,
#               min_child_samples=60, n_estimators=806, n_jobs=-1, num_leaves=263,
#               random_state=42, subsample=0.711751289956135)
#
# --- ALL MODELS SAVED TO DISK ---
# Models are saved in: ../models/lightgbm
# Optuna studies are saved in: ../optuna_db
