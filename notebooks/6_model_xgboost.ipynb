# %% [markdown]
# # XGBoost Model Development
#
# **XGBoost** is an optimized distributed gradient boosting library designed to be highly efficient, flexible, and portable. It implements machine learning algorithms under the Gradient Boosting framework. XGBoost provides a parallel tree boosting (also known as GBDT, GBM) that solves many data science problems in a fast and accurate way.

# %% [markdown]
# ### 1. Load the Datasets

# %%
import pandas as pd
from pathlib import Path

# Directory where the processed data is stored
data_path = Path("../processed_data")

# Load the training and validation datasets
X_train, X_val, y_train, y_val = (
    pd.read_csv(data_path / "X_train.csv"),
    pd.read_csv(data_path / "X_val.csv"),
    pd.read_csv(data_path / "y_train.csv"),
    pd.read_csv(data_path / "y_val.csv")
)

# Combine train and validation sets for robust K-Fold tuning
features = pd.concat([X_train, X_val], ignore_index=True)
targets = pd.concat([y_train, y_val], ignore_index=True)

# Display the shapes of the datasets
print(f"features shape: {features.shape}")
print(f"targets shape: {targets.shape}")
# Out:
# features shape: (2000, 157)
# targets shape: (2000, 10)

# %% [markdown]
# ### 2. Hyperparameter Tuning & Model Training

# %%
import optuna
import warnings
import numpy as np
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_percentage_error

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")

# Define the objective function for Optuna
def objective(trial: optuna.Trial, X: pd.DataFrame, y: pd.Series):
    """
    Objective function for Optuna to minimize Mean Absolute Percentage Error (MAPE)
    using an XGBoost Regressor with K-Fold cross-validation.

    Parameters:
      trial (optuna.Trial): An Optuna trial object that suggests hyperparameters.
      X (pd.DataFrame): Feature matrix for training.
      y (pd.Series): Target variable for training.

    Returns:
      float: The mean absolute percentage error (MAPE) of the model on the validation set during cross-validation.
    """
    # Define the hyperparameter search space for XGBoost
    param = {
        'objective': 'reg:squarederror',
        'eval_metric': 'mape',
        'early_stopping_round': 10,
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 5),
        'random_state': 42,
        'n_jobs': -1
    }

    # Use K-Fold cross-validation to get a robust estimate of the model's performance
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    mape_scores = []
    for train_index, val_index in kf.split(X):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        model = xgb.XGBRegressor(**param)
        model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=False)
        preds = model.predict(X_val)
        mape_scores.append(mean_absolute_percentage_error(y_val, preds))

    return np.mean(mape_scores)

# %%
import joblib

# Define the directory for saving models and Optuna studies
model_dir = Path("../models/xgboost")
model_dir.mkdir(parents=True, exist_ok=True)

optuna_dir = Path("../optuna_db")
optuna_dir.mkdir(parents=True, exist_ok=True)
storage_name = f"sqlite:///{optuna_dir}/xgboost_studies.db"

# Dictionary to store the best models
best_models = {}

# Iterate over each target property to tune and train a model
for target in targets.columns:
    print(f"\n--- Tuning and Training for {target} ---\n")
    y = targets[target]

    # Create an Optuna study to find the best hyperparameters
    study = optuna.create_study(direction='minimize',
                                study_name='lightgbm-tuning-' + target,
                                storage=storage_name)
    study.optimize(lambda trial: objective(trial, features, y), n_trials=50)

    # Get the best hyperparameters
    best_params = study.best_params
    print(f"Best MAPE for {target}: {study.best_value}")
    print(f"Best hyperparameters for {target}: {best_params}")

    # Train the final model with the best hyperparameters on the entire training set
    final_model = xgb.XGBRegressor(**best_params, random_state=42, n_jobs=-1)
    final_model.fit(features, y)

    # Save the trained model to a file
    joblib.dump(final_model, f'{model_dir}/{target}_model.joblib')
    print(f"Saved best model for {target}")

    # Store the best model with its MAPE score in the dictionary
    best_models[target] = (final_model, study.best_value)
# Out:
# --- Tuning and Training for BlendProperty1 ---
# [I 2025-07-18 18:02:10,912] A new study created in RDB with name: lightgbm-tuning-BlendProperty1
# [I 2025-07-18 18:02:18,871] Trial 0 finished with value: 4.141636731702515 and parameters: {'n_estimators': 371, 'learning_rate': 0.12336954551514612, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.6645881996196517, 'colsample_bytree': 0.9274202984276753, 'gamma': 0.9768356863092365}. Best is trial 0 with value: 4.141636731702515.
# [I 2025-07-18 18:02:27,523] Trial 1 finished with value: 1.8327686129433811 and parameters: {'n_estimators': 599, 'learning_rate': 0.2710510703021149, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.6027453482840737, 'colsample_bytree': 0.9304553850344833, 'gamma': 0.4868454381737741}. Best is trial 1 with value: 1.8327686129433811.
# [I 2025-07-18 18:02:51,336] Trial 2 finished with value: 3.4797449080854412 and parameters: {'n_estimators': 995, 'learning_rate': 0.06564972684491026, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8530743981135607, 'colsample_bytree': 0.8849316296569472, 'gamma': 0.035986939610828106}. Best is trial 1 with value: 1.8327686129433811.
# [I 2025-07-18 18:03:02,797] Trial 3 finished with value: 2.6889462976318077 and parameters: {'n_estimators': 776, 'learning_rate': 0.12412422353976489, 'max_depth': 9, 'min_child_weight': 1, 'subsample': 0.8175034964266861, 'colsample_bytree': 0.6528213350782096, 'gamma': 1.86603932600934}. Best is trial 1 with value: 1.8327686129433811.
# [I 2025-07-18 18:03:14,065] Trial 4 finished with value: 4.054902407208619 and parameters: {'n_estimators': 606, 'learning_rate': 0.03501875702030182, 'max_depth': 4, 'min_child_weight': 9, 'subsample': 0.8105667441868727, 'colsample_bytree': 0.9471204272984268, 'gamma': 4.79237141266872}. Best is trial 1 with value: 1.8327686129433811.
# [I 2025-07-18 18:03:22,580] Trial 5 finished with value: 1.2338538485097144 and parameters: {'n_estimators': 477, 'learning_rate': 0.267234133916425, 'max_depth': 11, 'min_child_weight': 3, 'subsample': 0.7043680546105971, 'colsample_bytree': 0.8386801116197806, 'gamma': 1.3318591646460542}. Best is trial 5 with value: 1.2338538485097144.
# [I 2025-07-18 18:03:47,198] Trial 6 finished with value: 2.5995376237794465 and parameters: {'n_estimators': 951, 'learning_rate': 0.19823935393483602, 'max_depth': 6, 'min_child_weight': 3, 'subsample': 0.656776998102598, 'colsample_bytree': 0.8336520212722947, 'gamma': 2.2660223935921042}. Best is trial 5 with value: 1.2338538485097144.
# [I 2025-07-18 18:04:10,776] Trial 7 finished with value: 3.434672796610142 and parameters: {'n_estimators': 803, 'learning_rate': 0.010419622432640099, 'max_depth': 6, 'min_child_weight': 2, 'subsample': 0.775673371693409, 'colsample_bytree': 0.778840583570353, 'gamma': 3.1648703279664367}. Best is trial 5 with value: 1.2338538485097144.
 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.7116306190313378, 'colsample_bytree': 0.8404004884680544, 'gamma': 2.3161740994705817}. Best is trial 24 with value: 1.1241262852486753.
# [I 2025-07-18 18:11:31,493] Trial 49 finished with value: 4.090295359202647 and parameters: {'n_estimators': 414, 'learning_rate': 0.245883556425817, 'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.6546342957047777, 'colsample_bytree': 0.7777799945305527, 'gamma': 1.113640657782409}. Best is trial 24 with value: 1.1241262852486753.
# Best MAPE for BlendProperty1: 1.1241262852486753
# Best hyperparameters for BlendProperty1: {'n_estimators': 880, 'learning_rate': 0.22507387950939334, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6978817111166078, 'colsample_bytree': 0.8463349997475814, 'gamma': 2.8690698326696795}
# [I 2025-07-18 18:11:36,715] A new study created in RDB with name: lightgbm-tuning-BlendProperty2
# Saved best model for BlendProperty1
#
# --- Tuning and Training for BlendProperty2 ---
# [I 2025-07-18 18:11:46,485] Trial 0 finished with value: 1.1002017132746689 and parameters: {'n_estimators': 607, 'learning_rate': 0.2614929109044249, 'max_depth': 11, 'min_child_weight': 10, 'subsample': 0.8782122807079289, 'colsample_bytree': 0.7227047112202676, 'gamma': 1.4303406413260182}. Best is trial 0 with value: 1.1002017132746689.
# [I 2025-07-18 18:11:59,704] Trial 1 finished with value: 0.927929783607872 and parameters: {'n_estimators': 941, 'learning_rate': 0.07495811255311499, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.9968521136229886, 'colsample_bytree': 0.9710798062461475, 'gamma': 4.2862014678802325}. Best is trial 1 with value: 0.927929783607872.
# [I 2025-07-18 18:12:07,655] Trial 2 finished with value: 1.3170733076058927 and parameters: {'n_estimators': 515, 'learning_rate': 0.25272536336898854, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 0.6101684621395093, 'colsample_bytree': 0.9586262544975117, 'gamma': 2.024317046038116}. Best is trial 1 with value: 0.927929783607872.
# [I 2025-07-18 18:12:25,603] Trial 3 finished with value: 0.8994132498250401 and parameters: {'n_estimators': 561, 'learning_rate': 0.021654286393734703, 'max_depth': 9, 'min_child_weight': 9, 'subsample': 0.8004282466508312, 'colsample_bytree': 0.8887201201292199, 'gamma': 1.424686658748267}. Best is trial 3 with value: 0.8994132498250401.
# [I 2025-07-18 18:12:40,886] Trial 4 finished with value: 1.023495050234572 and parameters: {'n_estimators': 453, 'learning_rate': 0.08139381531839955, 'max_depth': 9, 'min_child_weight': 4, 'subsample': 0.8672026565246069, 'colsample_bytree': 0.8471170723946725, 'gamma': 0.5719721795178828}. Best is trial 3 with value: 0.8994132498250401.
# [I 2025-07-18 18:12:53,921] Trial 5 finished with value: 1.0849574455793536 and parameters: {'n_estimators': 889, 'learning_rate': 0.10069254650495287, 'max_depth': 12, 'min_child_weight': 6, 'subsample': 0.9245907010005722, 'colsample_bytree': 0.8532931679949012, 'gamma': 4.131655303511695}. Best is trial 3 with value: 0.8994132498250401.
# [I 2025-07-18 18:13:06,975] Trial 6 finished with value: 1.3929038920360504 and parameters: {'n_estimators': 628, 'learning_rate': 0.2785325268760063, 'max_depth': 11, 'min_child_weight': 4, 'subsample': 0.6890475911723707, 'colsample_bytree': 0.7595968128988518, 'gamma': 0.07113155885424105}. Best is trial 3 with value: 0.8994132498250401.
# [I 2025-07-18 18:27:20,140] Trial 44 finished with value: 0.7490125754431023 and parameters: {'n_estimators': 881, 'learning_rate': 0.031639531607786084, 'max_depth': 11, 'min_child_weight': 4, 'subsample': 0.6388976896805755, 'colsample_bytree': 0.9517791098474123, 'gamma': 0.21755635143650698}. Best is trial 43 with value: 0.7361791339023062.
# [I 2025-07-18 18:27:41,150] Trial 45 finished with value: 1.0444950011111782 and parameters: {'n_estimators': 961, 'learning_rate': 0.29840648624904487, 'max_depth': 12, 'min_child_weight': 4, 'subsample': 0.6035896964415554, 'colsample_bytree': 0.9835767985413919, 'gamma': 0.20284030494455624}. Best is trial 43 with value: 0.7361791339023062.
# [I 2025-07-18 18:27:59,693] Trial 46 finished with value: 0.85774148599595 and parameters: {'n_estimators': 907, 'learning_rate': 0.06844771827748868, 'max_depth': 11, 'min_child_weight': 4, 'subsample': 0.6313252269116191, 'colsample_bytree': 0.9612176919402956, 'gamma': 0.509761156999585}. Best is trial 43 with value: 0.7361791339023062.
# [I 2025-07-18 18:28:23,050] Trial 47 finished with value: 0.7702190962830363 and parameters: {'n_estimators': 874, 'learning_rate': 0.02907415826634546, 'max_depth': 11, 'min_child_weight': 4, 'subsample': 0.6523790756313546, 'colsample_bytree': 0.9515510649514908, 'gamma': 0.7058662352059493}. Best is trial 43 with value: 0.7361791339023062.
# [I 2025-07-18 18:28:48,809] Trial 48 finished with value: 0.875672070955457 and parameters: {'n_estimators': 856, 'learning_rate': 0.029664393576884017, 'max_depth': 11, 'min_child_weight': 3, 'subsample': 0.6542069828446669, 'colsample_bytree': 0.9868690103094275, 'gamma': 1.226203461412026}. Best is trial 43 with value: 0.7361791339023062.
# [I 2025-07-18 18:29:07,692] Trial 49 finished with value: 0.8038279568507587 and parameters: {'n_estimators': 979, 'learning_rate': 0.057962123580305155, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 0.6503452649126085, 'colsample_bytree': 0.9515095526068628, 'gamma': 0.6448106835059357}. Best is trial 43 with value: 0.7361791339023062.
# Best MAPE for BlendProperty2: 0.7361791339023062
# Best hyperparameters for BlendProperty2: {'n_estimators': 852, 'learning_rate': 0.028984637397741222, 'max_depth': 10, 'min_child_weight': 4, 'subsample': 0.6426589058512316, 'colsample_bytree': 0.9565959429780223, 'gamma': 0.24319246921625806}
# [I 2025-07-18 18:29:14,217] A new study created in RDB with name: lightgbm-tuning-BlendProperty3
# Saved best model for BlendProperty2
#
# --- Tuning and Training for BlendProperty3 ---
# [I 2025-07-18 18:29:24,113] Trial 0 finished with value: 1.4558833952232137 and parameters: {'n_estimators': 617, 'learning_rate': 0.13667540152134555, 'max_depth': 6, 'min_child_weight': 10, 'subsample': 0.6792724623395565, 'colsample_bytree': 0.9545057481869889, 'gamma': 1.5341544697736187}. Best is trial 0 with value: 1.4558833952232137.
# [I 2025-07-18 18:29:36,688] Trial 1 finished with value: 1.4987255175071268 and parameters: {'n_estimators': 573, 'learning_rate': 0.2887397111147945, 'max_depth': 9, 'min_child_weight': 2, 'subsample': 0.8864004651817182, 'colsample_bytree': 0.6975810592889595, 'gamma': 1.9344185199672903}. Best is trial 0 with value: 1.4558833952232137.
 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.98784401192824, 'colsample_bytree': 0.8372622695913967, 'gamma': 0.0005043749204015624}. Best is trial 11 with value: 1.134535460825696.
# [I 2025-07-18 18:32:58,621] Trial 12 finished with value: 1.0844630660453143 and parameters: {'n_estimators': 366, 'learning_rate': 0.025529898311368, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.9958239775828244, 'colsample_bytree': 0.8065148798518814, 'gamma': 0.06340489362651719}. Best is trial 12 with value: 1.0844630660453143.
# [I 2025-07-18 18:33:09,528] Trial 13 finished with value: 1.5026414989138162 and parameters: {'n_estimators': 361, 'learning_rate': 0.013236653478456572, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.9342185865899353, 'colsample_bytree': 0.7908286113792449, 'gamma': 1.1116753980016756}. Best is trial 12 with value: 1.0844630660453143.
# [I 2025-07-18 18:34:04,942] Trial 14 finished with value: 1.2316400978068525 and parameters: {'n_estimators': 405, 'learning_rate': 0.011474896255838361, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.9216084671986642, 'colsample_bytree': 0.6253772001153081, 'gamma': 0.08016942371504765}. Best is trial 12 with value: 1.0844630660453143.
# [I 2025-07-18 18:34:15,262] Trial 15 finished with value: 1.3079165126170484 and parameters: {'n_estimators': 466, 'learning_rate': 0.08096381896535759, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.9981463473590553, 'colsample_bytree': 0.8767862749401298, 'gamma': 0.7797645506194483}. Best is trial 12 with value: 1.0844630660453143.
# [I 2025-07-18 18:34:34,161] Trial 16 finished with value: 1.3153121772538687 and parameters: {'n_estimators': 733, 'learning_rate': 0.04420486727800203, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.827836899508015, 'colsample_bytree': 0.7900115294794012, 'gamma': 1.4896530056833446}. Best is trial 12 with value: 1.0844630660453143.
# [I 2025-07-18 18:34:46,039] Trial 17 finished with value: 1.0321010452934707 and parameters: {'n_estimators': 476, 'learning_rate': 0.08162178316962118, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.7236777642323883, 'colsample_bytree': 0.8748667005043861, 'gamma': 0.10049373241987958}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:34:54,948] Trial 18 finished with value: 1.4521786145409397 and parameters: {'n_estimators': 476, 'learning_rate': 0.09201963981798122, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.7172380027091158, 'colsample_bytree': 0.8978319847628495, 'gamma': 1.5543521837359995}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:35:03,154] Trial 19 finished with value: 1.3053666350476771 and parameters: {'n_estimators': 484, 'learning_rate': 0.06773796974556527, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.6467952644698644, 'colsample_bytree': 0.7691543662694298, 'gamma': 0.5949723635931714}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:35:14,213] Trial 20 finished with value: 1.2721480251578412 and parameters: {'n_estimators': 710, 'learning_rate': 0.10869632980513234, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.7222688981623097, 'colsample_bytree': 0.8469292736666296, 'gamma': 1.120835806485494}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:35:39,690] Trial 21 finished with value: 1.1615346338642676 and parameters: {'n_estimators': 275, 'learning_rate': 0.021867818570746052, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.9116197779011047, 'colsample_bytree': 0.8237570252978119, 'gamma': 0.19920273666697025}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:36:16,558] Trial 22 finished with value: 1.1568457456367018 and parameters: {'n_estimators': 261, 'learning_rate': 0.03518440199747555, 'max_depth': 8, 'min_child_weight': 6, 'subsample': 0.8217627464666245, 'colsample_bytree': 0.8343073881995202, 'gamma': 0.007137183448015991}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:36:28,675] Trial 23 finished with value: 1.463461163711053 and parameters: {'n_estimators': 394, 'learning_rate': 0.06307790953344417, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.7867982157857704, 'colsample_bytree': 0.9091770057747443, 'gamma': 0.5966580065438353}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:36:38,785] Trial 24 finished with value: 1.333074828376302 and parameters: {'n_estimators': 142, 'learning_rate': 0.033348939482425906, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.7295843602576867, 'colsample_bytree': 0.7475930438554002, 'gamma': 0.08281519741957791}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:36:44,673] Trial 25 finished with value: 1.5028604407757935 and parameters: {'n_estimators': 335, 'learning_rate': 0.17869396725502967, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.6663952019635758, 'colsample_bytree': 0.8840059771083014, 'gamma': 1.2004920381575572}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:36:57,015] Trial 26 finished with value: 1.2919800157392776 and parameters: {'n_estimators': 493, 'learning_rate': 0.07014569954771205, 'max_depth': 8, 'min_child_weight': 3, 'subsample': 0.959597081772457, 'colsample_bytree': 0.9227269057322924, 'gamma': 0.5661881221288522}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:37:04,274] Trial 27 finished with value: 1.4199695167190651 and parameters: {'n_estimators': 420, 'learning_rate': 0.10517301523101802, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.7566795199665247, 'colsample_bytree': 0.8049869209671285, 'gamma': 1.9911012530483339}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:37:26,560] Trial 28 finished with value: 1.2426358299191214 and parameters: {'n_estimators': 195, 'learning_rate': 0.01108730728209156, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.9749809827408352, 'colsample_bytree': 0.8483295989783551, 'gamma': 0.8778817358406461}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:37:44,206] Trial 29 finished with value: 1.516059242792276 and parameters: {'n_estimators': 629, 'learning_rate': 0.03137763268792709, 'max_depth': 5, 'min_child_weight': 4, 'subsample': 0.70554749429017, 'colsample_bytree': 0.7827384240113434, 'gamma': 2.9209966258665534}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:37:55,430] Trial 30 finished with value: 1.2677260728746935 and parameters: {'n_estimators': 526, 'learning_rate': 0.05509071595685244, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.6392917018649866, 'colsample_bytree': 0.9918870553046177, 'gamma': 1.3905832007417442}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:38:10,339] Trial 31 finished with value: 1.1672616961189477 and parameters: {'n_estimators': 324, 'learning_rate': 0.039957839979708004, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.975811475497659, 'colsample_bytree': 0.8073986398568292, 'gamma': 0.33910968303732}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:38:24,338] Trial 32 finished with value: 1.2009168978828457 and parameters: {'n_estimators': 427, 'learning_rate': 0.05487621804525, 'max_depth': 8, 'min_child_weight': 3, 'subsample': 0.9427759931386424, 'colsample_bytree': 0.8200144164814158, 'gamma': 0.3728170430000146}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:38:41,489] Trial 33 finished with value: 1.141195608148777 and parameters: {'n_estimators': 318, 'learning_rate': 0.07876944661142568, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.9062121464530635, 'colsample_bytree': 0.7615882100475956, 'gamma': 0.019459916400700716}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:38:57,914] Trial 34 finished with value: 1.423570513502997 and parameters: {'n_estimators': 558, 'learning_rate': 0.023661777673783062, 'max_depth': 10, 'min_child_weight': 3, 'subsample': 0.9677868294067845, 'colsample_bytree': 0.8591769553880519, 'gamma': 1.77940873558315}. Best is trial 17 with value: 1.0321010452934707.
# [I 2025-07-18 18:39:05,988] Trial 35 finished with value: 1.3674031333347705 and parameters: {'n_estimators': 368, 'learning_rate': 0.13455080105050496, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.8740483498701265, 'colsample_bytree': 0.8355961032885769, 'gamma': 0.8232295960437217}. Best is trial 17 with value: 1.0321010452934707.
# ...
# [I 2025-07-18 19:42:07,743] Trial 5 finished with value: 1.0640464896394284 and parameters: {'n_estimators': 287, 'learning_rate': 0.14411070192563127, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 0.8941491325371924, 'colsample_bytree': 0.8893236649746046, 'gamma': 3.9695560942704655}. Best is trial 2 with value: 0.8624816962546552.
# [I 2025-07-18 19:42:19,193] Trial 6 finished with value: 0.9229685110770458 and parameters: {'n_estimators': 727, 'learning_rate': 0.21492158030975964, 'max_depth': 10, 'min_child_weight': 2, 'subsample': 0.612449037593514, 'colsample_bytree': 0.929024796386847, 'gamma': 1.8522010002766294}. Best is trial 2 with value: 0.8624816962546552.
# [I 2025-07-18 19:42:28,024] Trial 7 finished with value: 1.0801090116623056 and parameters: {'n_estimators': 584, 'learning_rate': 0.2917266260214955, 'max_depth': 11, 'min_child_weight': 6, 'subsample': 0.6219457241590363, 'colsample_bytree': 0.6408229605064306, 'gamma': 3.063813031629283}. Best is trial 2 with value: 0.8624816962546552.
# [I 2025-07-18 19:42:39,602] Trial 8 finished with value: 1.1789394292784119 and parameters: {'n_estimators': 447, 'learning_rate': 0.13881463993888862, 'max_depth': 7, 'min_child_weight': 8, 'subsample': 0.87893016624486, 'colsample_bytree': 0.6221112692454123, 'gamma': 4.030669628500755}. Best is trial 2 with value: 0.8624816962546552.
# [I 2025-07-18 19:43:01,369] Trial 9 finished with value: 0.9897321556681049 and parameters: {'n_estimators': 920, 'learning_rate': 0.014621215757238574, 'max_depth': 11, 'min_child_weight': 3, 'subsample': 0.7637372081002856, 'colsample_bytree': 0.9391665678633146, 'gamma': 3.2061623857446033}. Best is trial 2 with value: 0.8624816962546552.
# [I 2025-07-18 19:43:06,205] Trial 10 finished with value: 0.6139697614246739 and parameters: {'n_estimators': 132, 'learning_rate': 0.08626299652353366, 'max_depth': 4, 'min_child_weight': 8, 'subsample': 0.9703389512376555, 'colsample_bytree': 0.7372780955661979, 'gamma': 0.07477394361274681}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:43:10,273] Trial 11 finished with value: 0.6507662849101978 and parameters: {'n_estimators': 153, 'learning_rate': 0.09512249640587618, 'max_depth': 3, 'min_child_weight': 8, 'subsample': 0.9902193539357007, 'colsample_bytree': 0.7267825300208655, 'gamma': 0.16020302733144165}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:43:13,889] Trial 12 finished with value: 0.6560135339737212 and parameters: {'n_estimators': 113, 'learning_rate': 0.09990394018063546, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.9826929624108957, 'colsample_bytree': 0.7375152688427332, 'gamma': 0.016146482402997195}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:43:16,875] Trial 13 finished with value: 0.7131255391686189 and parameters: {'n_estimators': 100, 'learning_rate': 0.11737118150815713, 'max_depth': 3, 'min_child_weight': 8, 'subsample': 0.9960279501983302, 'colsample_bytree': 0.7308179542233226, 'gamma': 0.13393449402090818}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:43:24,240] Trial 14 finished with value: 0.7771868735119247 and parameters: {'n_estimators': 289, 'learning_rate': 0.045718867919454925, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.9478047779790651, 'colsample_bytree': 0.8024501199279633, 'gamma': 0.7647960933673296}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:43:30,332] Trial 15 finished with value: 1.0088403279202267 and parameters: {'n_estimators': 253, 'learning_rate': 0.17526564366770114, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.9367462072081556, 'colsample_bytree': 0.7345329040146585, 'gamma': 0.6150297080582624}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:43:41,041] Trial 16 finished with value: 0.8710793769348861 and parameters: {'n_estimators': 435, 'learning_rate': 0.05942787245118198, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8365204182350123, 'colsample_bytree': 0.8585914706518927, 'gamma': 1.0790195714032733}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:43:49,594] Trial 17 finished with value: 1.0676328850407835 and parameters: {'n_estimators': 195, 'learning_rate': 0.011220438852708237, 'max_depth': 4, 'min_child_weight': 8, 'subsample': 0.9498688072439873, 'colsample_bytree': 0.6886822321506462, 'gamma': 2.2673485066563055}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:43:57,420] Trial 18 finished with value: 0.7624946874201453 and parameters: {'n_estimators': 411, 'learning_rate': 0.09107831814758141, 'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.852456956704074, 'colsample_bytree': 0.7613018103160368, 'gamma': 0.40938221049846313}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:44:00,993] Trial 19 finished with value: 0.8615699132263341 and parameters: {'n_estimators': 184, 'learning_rate': 0.16265632214206172, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.9914550595434917, 'colsample_bytree': 0.7792213016676915, 'gamma': 1.3465155789033616}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:44:08,273] Trial 20 finished with value: 0.9830405888601941 and parameters: {'n_estimators': 377, 'learning_rate': 0.11877156202245251, 'max_depth': 9, 'min_child_weight': 9, 'subsample': 0.925209489854191, 'colsample_bytree': 0.9980377558803619, 'gamma': 2.2912912601954805}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:44:11,566] Trial 21 finished with value: 0.6553760815681426 and parameters: {'n_estimators': 100, 'learning_rate': 0.09494269600105594, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.9803429549986172, 'colsample_bytree': 0.6982103274138, 'gamma': 0.18366083376539416}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:44:16,931] Trial 22 finished with value: 0.6859042037566775 and parameters: {'n_estimators': 192, 'learning_rate': 0.08204153699864207, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.9615978951178049, 'colsample_bytree': 0.6906144176375042, 'gamma': 0.4441835799301017}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:44:23,215] Trial 23 finished with value: 0.6815850288942986 and parameters: {'n_estimators': 345, 'learning_rate': 0.11444066251180218, 'max_depth': 3, 'min_child_weight': 8, 'subsample': 0.9975403720212804, 'colsample_bytree': 0.694520151015489, 'gamma': 0.07570767962588593}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:44:36,394] Trial 24 finished with value: 0.7716450949870423 and parameters: {'n_estimators': 509, 'learning_rate': 0.05513601040047163, 'max_depth': 4, 'min_child_weight': 6, 'subsample': 0.9111429335486341, 'colsample_bytree': 0.8477489467337497, 'gamma': 0.8452244894858028}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:44:40,575] Trial 25 finished with value: 0.8903989082019326 and parameters: {'n_estimators': 100, 'learning_rate': 0.1286491971388535, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.8719829301440286, 'colsample_bytree': 0.7067260799029008, 'gamma': 0.39398798791355305}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:44:45,704] Trial 26 finished with value: 0.9413166075539661 and parameters: {'n_estimators': 174, 'learning_rate': 0.03254752339009768, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9652075708325915, 'colsample_bytree': 0.8246237758267877, 'gamma': 1.2907863928215635}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:44:51,891] Trial 27 finished with value: 0.6815996704443672 and parameters: {'n_estimators': 229, 'learning_rate': 0.07395711589847108, 'max_depth': 5, 'min_child_weight': 7, 'subsample': 0.7021764595179119, 'colsample_bytree': 0.7555851121527235, 'gamma': 0.7129599555518533}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:45:03,520] Trial 28 finished with value: 0.7169101219507125 and parameters: {'n_estimators': 318, 'learning_rate': 0.10317943008754474, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.800780332952307, 'colsample_bytree': 0.6559033253029898, 'gamma': 0.008183846838764969}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:45:17,516] Trial 29 finished with value: 1.183093432157968 and parameters: {'n_estimators': 995, 'learning_rate': 0.2501091409577938, 'max_depth': 3, 'min_child_weight': 6, 'subsample': 0.9249785505986997, 'colsample_bytree': 0.7199694089276452, 'gamma': 1.924613739825116}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:45:20,990] Trial 30 finished with value: 1.0049229831390036 and parameters: {'n_estimators': 164, 'learning_rate': 0.1677912699632707, 'max_depth': 4, 'min_child_weight': 8, 'subsample': 0.9650112163710035, 'colsample_bytree': 0.776335720324083, 'gamma': 1.5774273279313258}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:45:24,246] Trial 31 finished with value: 0.7887831039148328 and parameters: {'n_estimators': 103, 'learning_rate': 0.09738102333567945, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.9776837970460557, 'colsample_bytree': 0.7460259588363857, 'gamma': 0.3184632670489388}. Best is trial 10 with value: 0.6139697614246739.
# [I 2025-07-18 19:45:28,706] Trial 32 finished with value: 0.597802886377014 and parameters: {'n_estimators': 140, 'learning_rate': 0.07885605063192688, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.9812543671296039, 'colsample_bytree': 0.6765990082833855, 'gamma': 0.05835828780964476}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:45:38,147] Trial 33 finished with value: 0.8714948240594845 and parameters: {'n_estimators': 245, 'learning_rate': 0.07486854877204015, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9297983089461099, 'colsample_bytree': 0.6791490067665734, 'gamma': 0.9597457453897094}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:45:42,061] Trial 34 finished with value: 0.7683762458268839 and parameters: {'n_estimators': 166, 'learning_rate': 0.14751475868442943, 'max_depth': 5, 'min_child_weight': 5, 'subsample': 0.9991184968953257, 'colsample_bytree': 0.6671418235132717, 'gamma': 0.5317276534460393}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:45:47,280] Trial 35 finished with value: 0.8849137469335405 and parameters: {'n_estimators': 147, 'learning_rate': 0.1904544204171873, 'max_depth': 8, 'min_child_weight': 9, 'subsample': 0.9694711680282554, 'colsample_bytree': 0.714144639992872, 'gamma': 0.2531371046153684}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:45:56,871] Trial 36 finished with value: 0.9029288183759562 and parameters: {'n_estimators': 232, 'learning_rate': 0.027633959931557574, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.8984304401720818, 'colsample_bytree': 0.6336177276162716, 'gamma': 1.2536161568528057}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:46:02,544] Trial 37 finished with value: 0.7731558072756286 and parameters: {'n_estimators': 290, 'learning_rate': 0.0599086216712867, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8314390397223338, 'colsample_bytree': 0.6054607274068674, 'gamma': 0.6398252304394016}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:46:10,604] Trial 38 finished with value: 1.1997858025292805 and parameters: {'n_estimators': 483, 'learning_rate': 0.08508695297279927, 'max_depth': 7, 'min_child_weight': 8, 'subsample': 0.7097055371956079, 'colsample_bytree': 0.6609516389492561, 'gamma': 4.890682986276658}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:46:18,049] Trial 39 finished with value: 0.845158969704811 and parameters: {'n_estimators': 362, 'learning_rate': 0.1289808989815221, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.9405840318608258, 'colsample_bytree': 0.7757288678085484, 'gamma': 1.0252558254221489}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:46:30,701] Trial 40 finished with value: 0.9653827895580054 and parameters: {'n_estimators': 673, 'learning_rate': 0.04763578500491829, 'max_depth': 9, 'min_child_weight': 9, 'subsample': 0.7688308574047232, 'colsample_bytree': 0.7115691808974564, 'gamma': 3.7082839727929344}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:46:37,899] Trial 41 finished with value: 0.6840495079421335 and parameters: {'n_estimators': 134, 'learning_rate': 0.10408393000487685, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.9786374039688822, 'colsample_bytree': 0.7469404137314639, 'gamma': 0.050383392681480274}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:46:42,156] Trial 42 finished with value: 0.7196129593301391 and parameters: {'n_estimators': 136, 'learning_rate': 0.07248957798462138, 'max_depth': 3, 'min_child_weight': 6, 'subsample': 0.9799135287125765, 'colsample_bytree': 0.7327117099005642, 'gamma': 0.24555613248266328}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:46:47,693] Trial 43 finished with value: 0.7083205194372276 and parameters: {'n_estimators': 208, 'learning_rate': 0.10159934196554118, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.9585047113435303, 'colsample_bytree': 0.6782852673090605, 'gamma': 0.055924438758469835}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:46:52,729] Trial 44 finished with value: 0.7221660179653031 and parameters: {'n_estimators': 276, 'learning_rate': 0.1316136825510279, 'max_depth': 4, 'min_child_weight': 8, 'subsample': 0.9128440492518624, 'colsample_bytree': 0.7005710278553393, 'gamma': 0.5360341226105969}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:46:56,298] Trial 45 finished with value: 0.7146865633978592 and parameters: {'n_estimators': 128, 'learning_rate': 0.11460031799162407, 'max_depth': 3, 'min_child_weight': 9, 'subsample': 0.6458031006925719, 'colsample_bytree': 0.7884517925047818, 'gamma': 0.2548353845533274}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:47:02,354] Trial 46 finished with value: 0.9297265599672775 and parameters: {'n_estimators': 215, 'learning_rate': 0.09284791940765702, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8842115744977351, 'colsample_bytree': 0.7247404605211991, 'gamma': 0.69934402205905}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:47:10,955] Trial 47 finished with value: 0.6579932808924335 and parameters: {'n_estimators': 139, 'learning_rate': 0.06157368058094503, 'max_depth': 5, 'min_child_weight': 6, 'subsample': 0.9451595207417025, 'colsample_bytree': 0.6478605249250203, 'gamma': 0.01216508166077514}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:47:23,589] Trial 48 finished with value: 1.0435436202430715 and parameters: {'n_estimators': 868, 'learning_rate': 0.14931741734582463, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.9870636628838364, 'colsample_bytree': 0.7637878462137329, 'gamma': 2.777381035299851}. Best is trial 32 with value: 0.597802886377014.
# [I 2025-07-18 19:47:36,662] Trial 49 finished with value: 0.8468487822897461 and parameters: {'n_estimators': 268, 'learning_rate': 0.07906102129478451, 'max_depth': 12, 'min_child_weight': 7, 'subsample': 0.9530689334075244, 'colsample_bytree': 0.8168625764896662, 'gamma': 0.807525341647239}. Best is trial 32 with value: 0.597802886377014.
# Best MAPE for BlendProperty10: 0.597802886377014
# Best hyperparameters for BlendProperty10: {'n_estimators': 140, 'learning_rate': 0.07885605063192688, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.9812543671296039, 'colsample_bytree': 0.6765990082833855, 'gamma': 0.05835828780964476}
# Saved best model for BlendProperty10

# %% [markdown]
# ### 3. List the Best Models with MAPE Scores

# %%
print("--- BEST MODELS AND MAPE SCORES ---\n")
for target, (model, mape) in best_models.items():
    print(f"{target}: MAPE = {mape:.4f}, Model = {model}")
print("--- ALL MODELS SAVED TO DISK ---\n")
print(f"Models are saved in: {model_dir}")
print(f"Optuna studies are saved in: {optuna_dir}")
# Out:
# --- BEST MODELS AND MAPE SCORES ---
#
# BlendProperty1: MAPE = 1.1241, Model = XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8463349997475814, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=2.8690698326696795, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.22507387950939334,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=880, n_jobs=-1,
#              num_parallel_tree=None, ...)
# BlendProperty2: MAPE = 0.7362, Model = XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9565959429780223, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.24319246921625806, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.028984637397741222,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=4, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=852, n_jobs=-1,
#              num_parallel_tree=None, ...)
# BlendProperty3: MAPE = 1.0321, Model = XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8748667005043861, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.10049373241987958, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.08162178316962118,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=476, n_jobs=-1,
#              num_parallel_tree=None, ...)
# BlendProperty4: MAPE = 0.7858, Model = XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8006761219334343, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.22350016984563037, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.09193583839271054,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=425, n_jobs=-1,
#              num_parallel_tree=None, ...)
# BlendProperty5: MAPE = 0.1084, Model = XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9786326642441552, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.1720418681846134, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.033077575590718146,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=9, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=387, n_jobs=-1,
#              num_parallel_tree=None, ...)
# BlendProperty6: MAPE = 0.5083, Model = XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6155627494231547, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.0033095618007862315, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.022152427802757575, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=7, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=786, n_jobs=-1,
#              num_parallel_tree=None, ...)
# BlendProperty7: MAPE = 1.2475, Model = XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8489057118340431, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.08389820949239107, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.20672246147027495,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=659, n_jobs=-1,
#              num_parallel_tree=None, ...)
# BlendProperty8: MAPE = 0.8355, Model = XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8322767171232157, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.20365762188005826, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.022224695560252732,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=10, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=816, n_jobs=-1,
#              num_parallel_tree=None, ...)
# BlendProperty9: MAPE = 1.2869, Model = XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7151321380366973, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.7974542821606588, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.14749442928467016,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=7, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=774, n_jobs=-1,
#              num_parallel_tree=None, ...)
# BlendProperty10: MAPE = 0.5978, Model = XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6765990082833855, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.05835828780964476, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.07885605063192688,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=5, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=140, n_jobs=-1,
#              num_parallel_tree=None, ...)
# --- ALL MODELS SAVED TO DISK ---
#
# Models are saved in: ../models/xgboost
# Optuna studies are saved in: ../optuna_db
